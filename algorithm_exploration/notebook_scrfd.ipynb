# %% [markdown]
# # Eksplorasi Algoritma Face Recognition (SCRFD Detector)
#
# Notebook ini bertujuan untuk membandingkan delapan metode pengenalan wajah sesuai dengan uji yang dilakukan di sistem GUI:
# 1. **Geometry-Based (Geometric Landmarks)**
# 2. **PCA (Holistik)**
# 3. **LBP (Berbasis Fitur)**
# 4. **HOG (Berbasis Fitur)**
# 5. **LBP + PCA (Hibrida)**
# 6. **DeepFace - Facenet (Deep Learning)**
# 7. **DeepFace - VGG-Face (Deep Learning)**
# 8. **DeepFace - ArcFace (Deep Learning)**
#
# Pengujian dilakukan dengan mencocokkan foto selfie kueri (Person A, B, C) dengan seluruh 1000 gambar uji di dataset, menggunakan metode pencocokan jarak Cosine langsung (tanpa SVM) seperti pada sistem GUI. Evaluasi akan mencari threshold optimal untuk masing-masing model untuk perbandingan yang adil.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import time
import os
import psutil
import sys
import json
import hashlib
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from skimage.feature import local_binary_pattern, hog
from deepface import DeepFace
import pandas as pd

# Fungsi untuk mendapatkan penggunaan memori saat ini dalam MB
def get_memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)

# Menemukan project root
possible_roots = [
    os.path.abspath("."),
    os.path.abspath(".."),
    os.path.abspath("../..")
]
project_root = None
for root in possible_roots:
    if os.path.exists(os.path.join(root, "core")) and os.path.exists(os.path.join(root, "cache_io")):
        project_root = root
        break
if project_root is None:
    project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(f"Project root diatur ke: {project_root}")

from src.core.detector import FaceDetector
from src.cache_io.cache_handler import CacheHandler
# Out:
# WARNING:tensorflow:From c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Project root diatur ke: c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search

# %% [markdown]
# ## 1. Persiapan Dataset & Integrasi Cache
# Memuat dataset pengujian dari `D:\dataset\testset`, foto kueri dari `queries/`, ground truth dari `ground_truth.json`, dan inisialisasi model cache terpisah untuk masing-masing model Deep Learning menggunakan `CacheHandler` dari `cache_io`.

# %%
TESTSET_DIR = "D:/dataset/testset"
TEST_IMAGES_DIR = os.path.join(TESTSET_DIR, "test_case")
QUERIES_DIR = os.path.join(TESTSET_DIR, "queries")
GROUND_TRUTH_PATH = os.path.join(TESTSET_DIR, "ground_truth.json")

# 1. Load Ground Truth
with open(GROUND_TRUTH_PATH, "r", encoding="utf-8") as f:
    ground_truth = json.load(f)

test_images = [f for f in os.listdir(TEST_IMAGES_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
LIMIT_IMAGES = None  # Ganti dengan angka (misal 100) untuk pengujian cepat, atau None untuk seluruh gambar
if LIMIT_IMAGES is not None:
    test_images = test_images[:LIMIT_IMAGES]
print(f"Total Gambar Uji: {len(test_images)}")
print(f"Total Gambar di Ground Truth: {len(ground_truth)}")

# 2. Inisialisasi Face Detector
detector = FaceDetector("scrfd")

# 3. Subclass CacheHandler untuk menentukan direktori cache secara dinamis per model
class ModelCacheHandler(CacheHandler):
    def __init__(self, folder_input_path: str, model_name: str):
        super().__init__(folder_input_path)
        self.model_name = model_name.lower()
        self.cache_dir = os.path.join(self.folder_input_path, f".face_cache_scrfd_{self.model_name}")
        os.makedirs(self.cache_dir, exist_ok=True)

    def cache_exists(self, file_name: str, bbox: tuple) -> bool:
        bbox_str = f"_{bbox[0]}_{bbox[1]}_{bbox[2]}_{bbox[3]}"
        unique_id = hashlib.md5((file_name + bbox_str).encode('utf-8')).hexdigest()
        cache_file_path = os.path.join(self.cache_dir, f"{unique_id}.json")
        return os.path.exists(cache_file_path)

# 4. Load Preloaded Cache untuk efisiensi eksekusi notebook
models_dl = ["ArcFace", "Facenet", "VGG-Face"]
handlers = {model: ModelCacheHandler(TEST_IMAGES_DIR, model) for model in models_dl}
preloaded_caches = {}

for model in models_dl:
    print(f"Memuat cache untuk model {model}...")
    cache_list = handlers[model].muat_seluruh_cache()
    model_cache = {}
    for entry in cache_list:
        img_name = entry["file_name"]
        if img_name not in model_cache:
            model_cache[img_name] = []
        model_cache[img_name].append(entry)
    preloaded_caches[model] = model_cache

# 5. Helper untuk memuat wajah (face ROIs) — selalu menggunakan detector untuk alignment konsisten
def get_face_rois(img_path, detector):
    # Selalu jalankan detector.detect_and_crop agar affine alignment 5-titik diterapkan
    # secara konsisten di setiap run, tanpa bergantung pada cache bbox yang mungkin
    # dihasilkan oleh detector berbeda atau tanpa alignment.
    return detector.detect_and_crop(img_path)

def extract_deepface_embedding(face_img, model_name):
    if len(face_img.shape) == 2:
        face_img = cv2.cvtColor(face_img, cv2.COLOR_GRAY2BGR)
    elif face_img.shape[2] == 4:
        face_img = face_img[:, :, :3]
    # Downscale check for safe preprocessing
    h_f, w_f = face_img.shape[:2]
    if max(h_f, w_f) > 1080:
        scale_f = 1080.0 / max(h_f, w_f)
        face_img = cv2.resize(face_img, (int(w_f * scale_f), int(h_f * scale_f)), interpolation=cv2.INTER_AREA)
    objs = DeepFace.represent(
        img_path=face_img,
        model_name=model_name,
        enforce_detection=False,
        detector_backend="skip"
    )
    return np.array(objs[0]['embedding'], dtype=np.float32)

# 6. Ekstraksi Wajah untuk Kueri
queries = {
    "A": os.path.join(QUERIES_DIR, "selfie_A.jpeg"),
    "B": os.path.join(QUERIES_DIR, "selfie_B.jpg"),
    "C": os.path.join(QUERIES_DIR, "selfie_C.jpg")
}
query_faces = {}
for person, path in queries.items():
    faces = detector.detect_and_crop(path)
    if faces:
        query_faces[person] = faces[0]["cropped_face"]
        print(f"Wajah kueri Person {person} berhasil dideteksi.")
    else:
        raise RuntimeError(f"Gagal mendeteksi wajah pada kueri: {path}")

# 7. Kumpulkan semua wajah terdeteksi dari dataset gambar uji (Face Cropping tunggal untuk keadilan evaluasi)
print("Mengumpulkan wajah dari dataset gambar uji...")
t0 = time.time()
dataset_faces = [] # list of dict: {"img_name": str, "cropped_face": np.ndarray, "bbox": tuple}
for img_name in test_images:
    img_path = os.path.join(TEST_IMAGES_DIR, img_name)
    rois = get_face_rois(img_path, detector)
    for roi in rois:
        dataset_faces.append({
            "img_name": img_name,
            "cropped_face": roi["cropped_face"],
            "bbox": roi["bbox"]
        })
detection_time = time.time() - t0
print(f"Berhasil mengumpulkan {len(dataset_faces)} wajah dari {len(test_images)} gambar uji dalam {detection_time:.2f} detik (deteksi+alignment).")

# Penampung hasil komparasi
results = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-Score': [],
    'Best Threshold': [],
    'Feature Extraction Time (s)': [],
    'Inference Time (s)': [],
    'Memory Usage (MB)': [],
    'Detection Time (s)': []
}

# Fungsi pembantu evaluasi umum
def evaluate_matching_model(model_name, query_feats, dataset_feats, dataset_face_metadata, feat_extract_time, mem_used):
    t0 = time.time()
    # Evaluasi jarak Cosine secara matriks/ter-vektorisasi
    # query_feats: dict of {person: vector}
    # dataset_feats: array of shape (N_faces, dim)
    
    persons = ["A", "B", "C"]
    # Hitung semua jarak Cosine antara kueri dan wajah di dataset
    # Jarak Cosine = 1.0 - Cosine Similarity
    distances = {}
    for p in persons:
        q_feat = query_feats[p]
        q_norm = q_feat / (np.linalg.norm(q_feat) + 1e-10)
        
        # dataset_feats shape (N, dim)
        ds_norms = np.linalg.norm(dataset_feats, axis=1, keepdims=True) + 1e-10
        ds_normed = dataset_feats / ds_norms
        
        sims = np.dot(ds_normed, q_norm)
        sims = np.clip(sims, -1.0, 1.0)
        distances[p] = 1.0 - sims
        
    # Mencari threshold optimal dari 0.05 ke 0.95 dengan step 0.05
    thresholds = np.arange(0.05, 1.0, 0.05)
    best_f1 = -1
    best_thresh = 0.4
    best_metrics = {}
    
    # Struktur data target (ground truth)
    # Bentuk ground truth flat (1000 gambar * 3 orang = 3000 pasang)
    y_true = []
    for img_name in test_images:
        gt_img = ground_truth.get(img_name, {"contains_person_A": False, "contains_person_B": False, "contains_person_C": False})
        y_true.append(gt_img.get("contains_person_A", False))
        y_true.append(gt_img.get("contains_person_B", False))
        y_true.append(gt_img.get("contains_person_C", False))
    y_true = np.array(y_true, dtype=bool)
    
    # Lakukan grid search threshold
    for thresh in thresholds:
        # Lakukan prediksi untuk setiap gambar uji
        y_pred = []
        for img_name in test_images:
            # Cari indeks wajah-wajah yang terdeteksi di gambar ini
            indices = [i for i, meta in enumerate(dataset_face_metadata) if meta["img_name"] == img_name]
            
            for p in persons:
                if not indices:
                    # Tidak ada wajah terdeteksi
                    y_pred.append(False)
                else:
                    # Ambil jarak terkecil (wajah paling mirip) untuk kueri person p
                    min_dist = np.min(distances[p][indices])
                    y_pred.append(min_dist <= thresh)
                    
        y_pred = np.array(y_pred, dtype=bool)
        f1 = f1_score(y_true, y_pred, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_thresh = thresh
            best_metrics = {
                'Accuracy': accuracy_score(y_true, y_pred),
                'Precision': precision_score(y_true, y_pred, zero_division=0),
                'Recall': recall_score(y_true, y_pred, zero_division=0),
                'F1-Score': f1
            }
            
    infer_time = time.time() - t0
    
    # Catat ke tabel komparasi
    results['Model'].append(model_name)
    results['Accuracy'].append(best_metrics['Accuracy'])
    results['Precision'].append(best_metrics['Precision'])
    results['Recall'].append(best_metrics['Recall'])
    results['F1-Score'].append(best_metrics['F1-Score'])
    results['Best Threshold'].append(best_thresh)
    results['Feature Extraction Time (s)'].append(feat_extract_time)
    results['Inference Time (s)'].append(infer_time)
    results['Memory Usage (MB)'].append(mem_used)
    results['Detection Time (s)'].append(detection_time)
    
    print(f"--- {model_name} Evaluated ---")
    print(f"Best Threshold: {best_thresh:.2f}")
    print(f"Accuracy      : {best_metrics['Accuracy']:.4f}")
    print(f"F1-Score      : {best_metrics['F1-Score']:.4f}")
# Out:
# 2026-06-22 00:33:14,076 - INFO - Menginisialisasi detektor wajah SCRFD...
# Total Gambar Uji: 1000
# Total Gambar di Ground Truth: 1000
# 2026-06-22 00:33:14,552 - INFO - Detektor wajah SCRFD berhasil diinisialisasi dari c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\models\det_2.5g.onnx.
# 2026-06-22 00:33:14,554 - INFO - Direktori cache Zero-DB siap di: D:\dataset\testset\test_case\.face_cache
# 2026-06-22 00:33:14,556 - INFO - Direktori cache Zero-DB siap di: D:\dataset\testset\test_case\.face_cache
# 2026-06-22 00:33:14,557 - INFO - Direktori cache Zero-DB siap di: D:\dataset\testset\test_case\.face_cache
# 2026-06-22 00:33:14,559 - INFO - Menemukan 0 berkas cache di D:\dataset\testset\test_case\.face_cache_scrfd_arcface. Memulai pemuatan...
# 2026-06-22 00:33:14,560 - INFO - Berhasil memuat 0 data cache wajah yang valid ke dalam RAM.
# 2026-06-22 00:33:14,560 - INFO - Menemukan 0 berkas cache di D:\dataset\testset\test_case\.face_cache_scrfd_facenet. Memulai pemuatan...
# 2026-06-22 00:33:14,561 - INFO - Berhasil memuat 0 data cache wajah yang valid ke dalam RAM.
# 2026-06-22 00:33:14,562 - INFO - Menemukan 0 berkas cache di D:\dataset\testset\test_case\.face_cache_scrfd_vgg-face. Memulai pemuatan...
# 2026-06-22 00:33:14,562 - INFO - Berhasil memuat 0 data cache wajah yang valid ke dalam RAM.
# 2026-06-22 00:33:14,613 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# Memuat cache untuk model ArcFace...
# Memuat cache untuk model Facenet...
# Memuat cache untuk model VGG-Face...
# Wajah kueri Person A berhasil dideteksi.
# Wajah kueri Person B berhasil dideteksi.
# 2026-06-22 00:33:14,796 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:14,885 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# Wajah kueri Person C berhasil dideteksi.
# Mengumpulkan wajah dari dataset gambar uji...
# 2026-06-22 00:33:14,973 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,063 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,148 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,233 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,320 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,414 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,507 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,603 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,695 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,793 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,887 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:15,980 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:16,073 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:16,162 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:16,249 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:16,339 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:16,436 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:16,817 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:17,507 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-06-22 00:33:17,795 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:17,897 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:17,979 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,060 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,136 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,221 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,316 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,406 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,484 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,574 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,658 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:18,734 - INFO - Gambar resolusi tinggi di-downscale dari 1152x768 ke 1080x720 (max 1080px).
# 2026-06-22 00:33:18,796 - INFO - Gambar resolusi tinggi di-downscale dari 588x1280 ke 496x1080 (max 1080px).
# 2026-06-22 00:33:18,874 - INFO - Gambar resolusi tinggi di-downscale dari 640x1280 ke 540x1080 (max 1080px).
# 2026-06-22 00:33:19,061 - INFO - Gambar resolusi tinggi di-downscale dari 682x1280 ke 575x1080 (max 1080px).
# 2026-06-22 00:33:19,131 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-06-22 00:33:19,206 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-06-22 00:33:19,551 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-06-22 00:33:19,660 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-06-22 00:33:19,754 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-06-22 00:33:19,840 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-22 00:33:20,029 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-22 00:33:20,119 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:20,905 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:20,985 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-06-22 00:33:21,063 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-06-22 00:33:21,159 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-06-22 00:33:21,868 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-06-22 00:33:21,976 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:22,070 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-22 00:33:22,187 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-22 00:33:22,367 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:22,457 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:22,549 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:22,641 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:22,740 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1202 ke 1080x811 (max 1080px).
# 2026-06-22 00:33:22,828 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:22,911 - INFO - Gambar resolusi tinggi di-downscale dari 872x1160 ke 811x1080 (max 1080px).
# 2026-06-22 00:33:22,994 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:33:23,067 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-22 00:33:23,139 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-22 00:33:23,219 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-22 00:33:23,307 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-22 00:33:23,431 - INFO - Gambar resolusi tinggi di-downscale dari 896x1280 ke 756x1080 (max 1080px).
# 2026-06-22 00:33:23,538 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1261 ke 924x1080 (max 1080px).
# 2026-06-22 00:33:23,653 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1264 ke 922x1080 (max 1080px).
# 2026-06-22 00:33:23,753 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-06-22 00:33:23,863 - INFO - Gambar resolusi tinggi di-downscale dari 1066x1599 ke 720x1080 (max 1080px).
# 2026-06-22 00:33:23,963 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:24,100 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-22 00:33:24,182 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,274 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,364 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,466 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,559 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,658 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,765 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,860 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:24,962 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:25,061 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:25,152 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:25,264 - INFO - Gambar resolusi tinggi di-downscale dari 1197x1600 ke 807x1080 (max 1080px).
# 2026-06-22 00:33:25,367 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1197 ke 1080x807 (max 1080px).
# 2026-06-22 00:33:25,469 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1197 ke 1080x807 (max 1080px).
# 2026-06-22 00:33:25,568 - INFO - Gambar resolusi tinggi di-downscale dari 1197x1600 ke 807x1080 (max 1080px).
# 2026-06-22 00:33:25,673 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:25,752 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:25,865 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:26,042 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-22 00:33:26,197 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-22 00:33:26,287 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-22 00:33:26,385 - INFO - Gambar resolusi tinggi di-downscale dari 1477x1108 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:26,483 - INFO - Gambar resolusi tinggi di-downscale dari 1600x719 ke 1080x485 (max 1080px).
# 2026-06-22 00:33:26,584 - INFO - Gambar resolusi tinggi di-downscale dari 1600x903 ke 1080x609 (max 1080px).
# 2026-06-22 00:33:26,695 - INFO - Gambar resolusi tinggi di-downscale dari 1064x1600 ke 718x1080 (max 1080px).
# 2026-06-22 00:33:26,823 - INFO - Gambar resolusi tinggi di-downscale dari 1477x1108 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:26,916 - INFO - Gambar resolusi tinggi di-downscale dari 1599x901 ke 1080x608 (max 1080px).
# 2026-06-22 00:33:27,001 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:27,109 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-22 00:33:27,187 - INFO - Gambar resolusi tinggi di-downscale dari 1440x900 ke 1080x675 (max 1080px).
# 2026-06-22 00:33:27,295 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-22 00:33:27,403 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-22 00:33:27,495 - INFO - Gambar resolusi tinggi di-downscale dari 1365x768 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:27,570 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-06-22 00:33:27,673 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-22 00:33:27,771 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-22 00:33:27,976 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-22 00:33:28,060 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-22 00:33:28,152 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-22 00:33:28,404 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-22 00:33:28,667 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-22 00:33
- INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:12,778 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:13,035 - INFO - Gambar resolusi tinggi di-downscale dari 2296x4080 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:13,343 - INFO - Gambar resolusi tinggi di-downscale dari 4080x2296 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:13,607 - INFO - Gambar resolusi tinggi di-downscale dari 4080x2296 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:13,703 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:13,796 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:14,147 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:14,436 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:14,752 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:14,861 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:14,953 - INFO - Gambar resolusi tinggi di-downscale dari 1600x946 ke 1080x638 (max 1080px).
# 2026-06-22 00:34:15,024 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:15,122 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1074 ke 1080x724 (max 1080px).
# 2026-06-22 00:34:15,207 - INFO - Gambar resolusi tinggi di-downscale dari 1600x879 ke 1080x593 (max 1080px).
# 2026-06-22 00:34:15,287 - INFO - Gambar resolusi tinggi di-downscale dari 864x1152 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:15,411 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1204 ke 1080x812 (max 1080px).
# 2026-06-22 00:34:15,511 - INFO - Gambar resolusi tinggi di-downscale dari 1560x1040 ke 1080x720 (max 1080px).
# 2026-06-22 00:34:15,589 - INFO - Gambar resolusi tinggi di-downscale dari 1280x661 ke 1080x557 (max 1080px).
# 2026-06-22 00:34:15,710 - INFO - Gambar resolusi tinggi di-downscale dari 2928x1512 ke 1080x557 (max 1080px).
# 2026-06-22 00:34:15,779 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:15,860 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:15,940 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:16,147 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:16,345 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:16,563 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:16,774 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:16,984 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:17,191 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:17,394 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:17,613 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:17,838 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:18,055 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:18,150 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:18,234 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:18,480 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:18,560 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:18,695 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:18,759 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:18,825 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:18,891 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:18,962 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,028 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,094 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,161 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,229 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,289 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,357 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,423 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,495 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,562 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,637 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:19,710 - INFO - Gambar resolusi tinggi di-downscale dari 540x1170 ke 498x1080 (max 1080px).
# 2026-06-22 00:34:19,925 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:20,000 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:20,090 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:20,595 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-22 00:34:20,704 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:20,986 - INFO - Gambar resolusi tinggi di-downscale dari 708x1280 ke 597x1080 (max 1080px).
# 2026-06-22 00:34:21,125 - INFO - Gambar resolusi tinggi di-downscale dari 1156x521 ke 1080x486 (max 1080px).
# 2026-06-22 00:34:21,290 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:21,367 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:21,572 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:22,020 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:22,101 - INFO - Gambar resolusi tinggi di-downscale dari 1125x1150 ke 1056x1080 (max 1080px).
# 2026-06-22 00:34:22,192 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:22,632 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:22,715 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-06-22 00:34:22,889 - INFO - Gambar resolusi tinggi di-downscale dari 1125x385 ke 1080x369 (max 1080px).
# 2026-06-22 00:34:22,982 - INFO - Gambar resolusi tinggi di-downscale dari 1138x1600 ke 768x1080 (max 1080px).
# 2026-06-22 00:34:23,072 - INFO - Gambar resolusi tinggi di-downscale dari 1180x1377 ke 925x1080 (max 1080px).
# 2026-06-22 00:34:23,177 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:23,245 - INFO - Gambar resolusi tinggi di-downscale dari 719x1280 ke 606x1080 (max 1080px).
# 2026-06-22 00:34:23,342 - INFO - Gambar resolusi tinggi di-downscale dari 1202x1600 ke 811x1080 (max 1080px).
# 2026-06-22 00:34:23,518 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:23,620 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:23,731 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:23,908 - INFO - Gambar resolusi tinggi di-downscale dari 996x1280 ke 840x1080 (max 1080px).
# 2026-06-22 00:34:23,988 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-22 00:34:24,059 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-22 00:34:24,215 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-22 00:34:24,304 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-22 00:34:24,394 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-22 00:34:24,485 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-06-22 00:34:24,591 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-06
- INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-22 00:35:36,040 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# Berhasil mengumpulkan 7837 wajah dari 1000 gambar uji dalam 141.33 detik (deteksi+alignment).

# %% [markdown]
# ## 2. Metode Berbasis Geometri: Geometry-Based Landmarks
# Metode berbasis geometri mengidentifikasi wajah dengan mengukur jarak relatif antar landmark wajah utama seperti mata, hidung, dan mulut secara scale-invariant pada 6 jarak Euclidean berpasangan.

# %%
def extract_geometry_features(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    h_idx, w_idx = gray.shape
    
    def get_landmark_centroid(y_start, y_end, x_start, x_end):
        ys, ye = int(y_start * h_idx), int(y_end * h_idx)
        xs, xe = int(x_start * w_idx), int(x_end * w_idx)
        sub_img = gray[ys:ye, xs:xe]
        
        threshold = np.percentile(sub_img, 10)
        dark_pixels = np.argwhere(sub_img <= threshold)
        if len(dark_pixels) == 0:
            cy, cx = (ys + ye) / 2, (xs + xe) / 2
        else:
            cy = ys + np.mean(dark_pixels[:, 0])
            cx = xs + np.mean(dark_pixels[:, 1])
        return np.array([cx, cy])
        
    left_eye = get_landmark_centroid(0.2, 0.4, 0.2, 0.45)
    right_eye = get_landmark_centroid(0.2, 0.4, 0.55, 0.8)
    nose = get_landmark_centroid(0.45, 0.7, 0.4, 0.6)
    mouth = get_landmark_centroid(0.7, 0.95, 0.3, 0.7)
    
    dists = [
        np.linalg.norm(left_eye - right_eye),
        np.linalg.norm(left_eye - nose),
        np.linalg.norm(right_eye - nose),
        np.linalg.norm(left_eye - mouth),
        np.linalg.norm(right_eye - mouth),
        np.linalg.norm(nose - mouth)
    ]
    
    eye_dist = dists[0] if dists[0] > 0 else 1.0
    normalized_dists = [d / eye_dist for d in dists]
    return np.array(normalized_dists, dtype=np.float32)

print("Evaluasi Geometry-Based...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_geometry_features(face) for p, face in query_faces.items()}
dataset_feats = np.array([extract_geometry_features(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('Geometry-Based', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi Geometry-Based...
# --- Geometry-Based Evaluated ---
# Best Threshold: 0.05
# Accuracy      : 0.2900
# F1-Score      : 0.3990

# %% [markdown]
# ## 3. Metode Holistik: PCA (Eigenfaces)
# Principal Component Analysis (PCA) mereduksi dimensi gambar dari wajah ter-resize dengan memproyeksikannya ke eigenfaces berdimensi 150.

# %%
print("Evaluasi PCA (Eigenfaces)... ")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Flatten wajah ke grayscale
def flatten_gray_face(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    return gray.flatten().astype(np.float32) / 255.0

query_flat = np.array([flatten_gray_face(query_faces[p]) for p in ["A", "B", "C"]])
dataset_flat = np.array([flatten_gray_face(f["cropped_face"]) for f in dataset_faces])

# 2. Fit PCA pada kumpulan wajah dataset
n_components = min(150, len(dataset_faces))
pca = PCA(n_components=n_components, svd_solver='randomized', whiten=True)
pca.fit(dataset_flat)

# 3. Proyeksi
query_projected = pca.transform(query_flat)
dataset_projected = pca.transform(dataset_flat)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('PCA (Holistik)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi PCA (Eigenfaces)...
# --- PCA (Holistik) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.5143
# F1-Score      : 0.4529

# %% [markdown]
# ## 4. Metode Berbasis Fitur: LBP & HOG
# Mengekstrak fitur lokal menggunakan **Local Binary Pattern (LBP)** dan **Histogram of Oriented Gradients (HOG)**.

# %%
def extract_lbp_hist(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    n_bins = n_points + 2
    hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=(0, n_bins), density=True)
    return hist.astype(np.float32)

print("Evaluasi LBP...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_lbp_hist(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_lbp_hist(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

def extract_hog_vector(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    feat = hog(gray, orientations=8, pixels_per_cell=(8, 8),
               cells_per_block=(2, 2), visualize=False)
    return feat.astype(np.float32)

print("\nEvaluasi HOG...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_hog_vector(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_hog_vector(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('HOG (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP...
# --- LBP (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.30
# Accuracy      : 0.3720
# F1-Score      : 0.4189
#
# Evaluasi HOG...
# --- HOG (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.30
# Accuracy      : 0.5877
# F1-Score      : 0.4675

# %% [markdown]
# ## 5. Metode Hibrida: LBP + PCA
# Menggabungkan tekstur lokal dari LBP mentah dengan reduksi dimensi PCA (50 komponen).

# %%
def extract_raw_lbp(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    return lbp.ravel().astype(np.float32)

print("Evaluasi LBP + PCA (Hibrida)...")
mem_before = get_memory_usage()
t0 = time.time()

query_raw_lbp = np.array([extract_raw_lbp(query_faces[p]) for p in ["A", "B", "C"]])
dataset_raw_lbp = np.array([extract_raw_lbp(f["cropped_face"]) for f in dataset_faces])

n_components_hyb = min(50, len(dataset_faces))
pca_lbp = PCA(n_components=n_components_hyb, svd_solver='randomized', whiten=True)
pca_lbp.fit(dataset_raw_lbp)

query_projected = pca_lbp.transform(query_raw_lbp)
dataset_projected = pca_lbp.transform(dataset_raw_lbp)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP + PCA (Hibrida)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP + PCA (Hibrida)...
# --- LBP + PCA (Hibrida) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.4080
# F1-Score      : 0.3996

# %% [markdown]
# ## 6. Metode Deep Learning: Facenet (DeepFace)
# Mengekstrak embedding berdimensi 128 dari model Deep Learning Facenet (diload dari cache jika tersedia).

# %%
print("Evaluasi Facenet...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="Facenet", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    # Cek cache Facenet
    cached_found = False
    if img_name in preloaded_caches["Facenet"]:
        for cached_entry in preloaded_caches["Facenet"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        # Ekstraksi Baru dan simpan cache
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "Facenet")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["Facenet"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 100 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (Facenet)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi Facenet...
# --- DeepFace (Facenet) Evaluated ---
# Best Threshold: 0.40
# Accuracy      : 0.8890
# F1-Score      : 0.7630
# 759

# %% [markdown]
# ## 7. Metode Deep Learning: VGG-Face (DeepFace)
# Mengekstrak embedding berdimensi 2622 dari model Deep Learning VGG-Face (diload dari cache jika tersedia).

# %%
print("Evaluasi VGG-Face...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="VGG-Face", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["VGG-Face"]:
        for cached_entry in preloaded_caches["VGG-Face"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "VGG-Face")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["VGG-Face"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (VGG-Face)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi VGG-Face...
# --- DeepFace (VGG-Face) Evaluated ---
# Best Threshold: 0.60
# Accuracy      : 0.9220
# F1-Score      : 0.8186
# 338

# %% [markdown]
# ## 8. Metode Deep Learning: ArcFace (DeepFace)
# Mengekstrak embedding berdimensi 512 dari model Deep Learning ArcFace (diload dari cache jika tersedia). Ini adalah model yang digunakan oleh sistem utama GUI.

# %%
print("Evaluasi ArcFace...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="ArcFace", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["ArcFace"]:
        for cached_entry in preloaded_caches["ArcFace"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "ArcFace")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["ArcFace"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (ArcFace)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras setelah selesai pengujian
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi ArcFace...
# --- DeepFace (ArcFace) Evaluated ---
# Best Threshold: 0.60
# Accuracy      : 0.8910
# F1-Score      : 0.7547
# 140

# %% [markdown]
# ## 9. Visualisasi dan Perbandingan Kinerja
# Menampilkan tabel perbandingan DataFrame lengkap untuk kedelapan model, dan memvisualisasikan F1-Score, waktu eksekusi total (ekstraksi + pencocokan), serta tambahan penggunaan RAM.

# %%
df_results = pd.DataFrame(results)
print("\n--- Hasil Perbandingan Lengkap (8 Model) ---")
print(df_results.to_string(index=False))

# Tableau 10 color palette untuk visualisasi premium
colors = ['#4E79A7', '#F28E2B', '#E15759', '#76B7B2', '#59A14F', '#EDC948', '#B07AA1', '#FF9DA7']

plt.figure(figsize=(18, 6))

# 1. Plot F1-Score
plt.subplot(1, 3, 1)
bars1 = plt.bar(df_results['Model'], df_results['F1-Score'], color=colors[:len(df_results)])
plt.title('F1-Score Model (Tertinggi Terbaik)', fontsize=12, fontweight='bold')
plt.ylim(0, 1.15)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('F1-Score')
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.02, f"{yval:.2f}", ha='center', va='bottom', fontsize=9)

# 2. Plot Stacked Waktu Komputasi per Tahap (Deteksi + Ekstraksi + Inferensi)
plt.subplot(1, 3, 2)
det_times = df_results['Detection Time (s)']
feat_times = df_results['Feature Extraction Time (s)']
infer_times = df_results['Inference Time (s)']
plt.bar(df_results['Model'], det_times, color='#B07AA1', label='Deteksi & Alignment')
plt.bar(df_results['Model'], feat_times, bottom=det_times, color='#4E79A7', label='Ekstraksi Fitur')
plt.bar(df_results['Model'], infer_times, bottom=det_times + feat_times, color='#F28E2B', label='Inferensi/Matching')
total_time = det_times + feat_times + infer_times
plt.title('Waktu Komputasi per Tahap (detik)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Waktu (detik)')
plt.legend(fontsize=7, loc='upper left')
for i, total in enumerate(total_time):
    plt.text(i, total + (total * 0.02) + 0.05, f"{total:.2f}s", ha='center', va='bottom', fontsize=9)

# 3. Plot Memory Usage
plt.subplot(1, 3, 3)
bars3 = plt.bar(df_results['Model'], df_results['Memory Usage (MB)'], color=colors[:len(df_results)])
plt.title('Penggunaan Memori Tambahan (MB)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Memori (MB)')
for bar in bars3:
    yval = bar.get_height()
    # Jaga formatting
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.1, f"{yval:.1f} MB", ha='center', va='bottom', fontsize=9)

plt.tight_layout()
assets_dir = os.path.join(project_root, "assets")
os.makedirs(assets_dir, exist_ok=True)
plt.savefig(os.path.join(assets_dir, "perbandingan_kinerja_scrfd.png"), dpi=300, bbox_inches="tight")
plt.show()
# Out:
# --- Hasil Perbandingan Lengkap (8 Model) ---
#                Model  Accuracy  Precision   Recall  F1-Score  Best Threshold  Feature Extraction Time (s)  Inference Time (s)  Memory Usage (MB)  Detection Time (s)
#       Geometry-Based  0.290000   0.249207 1.000000  0.398984            0.05                     2.854128           10.009302           0.945312          141.329536
#       PCA (Holistik)  0.514333   0.308282 0.852900  0.452873            0.95                     5.522211           10.739054         417.066406          141.329536
# LBP (Berbasis Fitur)  0.372000   0.267850 0.960396  0.418877            0.30                    15.818657            9.571036           0.203125          141.329536
# HOG (Berbasis Fitur)  0.587667   0.336015 0.768034  0.467499            0.30                    24.706835            9.894295         164.617188          141.329536
#  LBP + PCA (Hibrida)  0.408000   0.262550 0.835926  0.399594            0.95                    14.041398           10.164680         375.601562          141.329536
#   DeepFace (Facenet)  0.889000   0.767908 0.758133  0.762989            0.40                  1761.458499           12.435488           0.000000          141.329536
#  DeepFace (VGG-Face)  0.922000   0.905660 0.746818  0.818605            0.60                  2147.132272           13.597491        1825.359375          141.329536
#   DeepFace (ArcFace)  0.891000   0.803514 0.711457  0.754689            0.60                  1524.226980           11.120317           0.000000          141.329536
