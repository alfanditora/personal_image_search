# %% [markdown]
# # Eksplorasi Algoritma Face Recognition (MTCNN Detector) + Uji Skalabilitas
#
# Notebook ini bertujuan untuk membandingkan delapan metode pengenalan wajah sesuai dengan uji yang dilakukan di sistem GUI:
# 1. **Geometry-Based (Geometric Landmarks)**
# 2. **PCA (Holistik)**
# 3. **LBP (Berbasis Fitur)**
# 4. **HOG (Berbasis Fitur)**
# 5. **LBP + PCA (Hibrida)**
# 6. **DeepFace - Facenet (Deep Learning)**
# 7. **DeepFace - VGG-Face (Deep Learning)**
# 8. **DeepFace - ArcFace (Deep Learning)**
#
# Pengujian dilakukan dengan mencocokkan foto selfie kueri (Person A, B, C) dengan seluruh 1000 gambar uji di dataset, menggunakan metode pencocokan jarak Cosine langsung (tanpa SVM) seperti pada sistem GUI. Evaluasi akan mencari threshold optimal untuk masing-masing model untuk perbandingan yang adil.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import time
import os
import psutil
import sys
import json
import hashlib
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from skimage.feature import local_binary_pattern, hog
from deepface import DeepFace
import pandas as pd

# Fungsi untuk mendapatkan penggunaan memori saat ini dalam MB
def get_memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)

# Menemukan project root
possible_roots = [
    os.path.abspath("."),
    os.path.abspath(".."),
    os.path.abspath("../..")
]
project_root = None
for root in possible_roots:
    if os.path.exists(os.path.join(root, "core")) and os.path.exists(os.path.join(root, "cache_io")):
        project_root = root
        break
if project_root is None:
    project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(f"Project root diatur ke: {project_root}")

from src.core.detector import FaceDetector
from src.cache_io.cache_handler import CacheHandler
# Out:
# WARNING:tensorflow:From c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Project root diatur ke: c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search

# %% [markdown]
# ## 1. Persiapan Dataset & Integrasi Cache
# Memuat dataset pengujian dari `D:\dataset\testset`, foto kueri dari `queries/`, ground truth dari `ground_truth.json`, dan inisialisasi model cache terpisah untuk masing-masing model Deep Learning menggunakan `CacheHandler` dari `cache_io`.

# %%
TESTSET_DIR = "D:/dataset/testset"
TEST_IMAGES_DIR = os.path.join(TESTSET_DIR, "test_case")
QUERIES_DIR = os.path.join(TESTSET_DIR, "queries")
GROUND_TRUTH_PATH = os.path.join(TESTSET_DIR, "ground_truth.json")

# 1. Load Ground Truth
with open(GROUND_TRUTH_PATH, "r", encoding="utf-8") as f:
    ground_truth = json.load(f)

test_images = [f for f in os.listdir(TEST_IMAGES_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
LIMIT_IMAGES = None  # Ganti dengan angka (misal 100) untuk pengujian cepat, atau None untuk seluruh gambar
if LIMIT_IMAGES is not None:
    test_images = test_images[:LIMIT_IMAGES]
print(f"Total Gambar Uji: {len(test_images)}")
print(f"Total Gambar di Ground Truth: {len(ground_truth)}")

# 2. Inisialisasi Face Detector
detector = FaceDetector("mtcnn")

# 3. Subclass CacheHandler untuk menentukan direktori cache secara dinamis per model
class ModelCacheHandler(CacheHandler):
    def __init__(self, folder_input_path: str, model_name: str):
        super().__init__(folder_input_path)
        self.model_name = model_name.lower()
        self.cache_dir = os.path.join(self.folder_input_path, f".face_cache_mtcnn_{self.model_name}")
        os.makedirs(self.cache_dir, exist_ok=True)

    def cache_exists(self, file_name: str, bbox: tuple) -> bool:
        bbox_str = f"_{bbox[0]}_{bbox[1]}_{bbox[2]}_{bbox[3]}"
        unique_id = hashlib.md5((file_name + bbox_str).encode('utf-8')).hexdigest()
        cache_file_path = os.path.join(self.cache_dir, f"{unique_id}.json")
        return os.path.exists(cache_file_path)

# 4. Load Preloaded Cache untuk efisiensi eksekusi notebook
models_dl = ["ArcFace", "Facenet", "VGG-Face"]
handlers = {model: ModelCacheHandler(TEST_IMAGES_DIR, model) for model in models_dl}
preloaded_caches = {}

for model in models_dl:
    print(f"Memuat cache untuk model {model}...")
    cache_list = handlers[model].muat_seluruh_cache()
    model_cache = {}
    for entry in cache_list:
        img_name = entry["file_name"]
        if img_name not in model_cache:
            model_cache[img_name] = []
        model_cache[img_name].append(entry)
    preloaded_caches[model] = model_cache

# 5. Helper untuk memuat wajah (face ROIs) — selalu menggunakan detector untuk alignment konsisten
def get_face_rois(img_path, detector):
    # Selalu jalankan detector.detect_and_crop agar affine alignment 5-titik diterapkan
    # secara konsisten di setiap run, tanpa bergantung pada cache bbox yang mungkin
    # dihasilkan oleh detector berbeda atau tanpa alignment.
    return detector.detect_and_crop(img_path)

def extract_deepface_embedding(face_img, model_name):
    if len(face_img.shape) == 2:
        face_img = cv2.cvtColor(face_img, cv2.COLOR_GRAY2BGR)
    elif face_img.shape[2] == 4:
        face_img = face_img[:, :, :3]
    # Downscale check for safe preprocessing
    h_f, w_f = face_img.shape[:2]
    if max(h_f, w_f) > 1080:
        scale_f = 1080.0 / max(h_f, w_f)
        face_img = cv2.resize(face_img, (int(w_f * scale_f), int(h_f * scale_f)), interpolation=cv2.INTER_AREA)
    objs = DeepFace.represent(
        img_path=face_img,
        model_name=model_name,
        enforce_detection=False,
        detector_backend="skip"
    )
    return np.array(objs[0]['embedding'], dtype=np.float32)

# 6. Ekstraksi Wajah untuk Kueri
queries = {
    "A": os.path.join(QUERIES_DIR, "selfie_A.jpeg"),
    "B": os.path.join(QUERIES_DIR, "selfie_B.jpg"),
    "C": os.path.join(QUERIES_DIR, "selfie_C.jpg")
}
query_faces = {}
for person, path in queries.items():
    faces = detector.detect_and_crop(path)
    if faces:
        query_faces[person] = faces[0]["cropped_face"]
        print(f"Wajah kueri Person {person} berhasil dideteksi.")
    else:
        raise RuntimeError(f"Gagal mendeteksi wajah pada kueri: {path}")

# 7. Kumpulkan semua wajah terdeteksi dari dataset gambar uji (Face Cropping tunggal untuk keadilan evaluasi)
print("Mengumpulkan wajah dari dataset gambar uji...")
t0 = time.time()
dataset_faces = [] # list of dict: {"img_name": str, "cropped_face": np.ndarray, "bbox": tuple}
for img_name in test_images:
    img_path = os.path.join(TEST_IMAGES_DIR, img_name)
    rois = get_face_rois(img_path, detector)
    for roi in rois:
        dataset_faces.append({
            "img_name": img_name,
            "cropped_face": roi["cropped_face"],
            "bbox": roi["bbox"]
        })
detection_time = time.time() - t0
print(f"Berhasil mengumpulkan {len(dataset_faces)} wajah dari {len(test_images)} gambar uji dalam {detection_time:.2f} detik (deteksi+alignment).")

# Penampung hasil komparasi
results = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-Score': [],
    'Best Threshold': [],
    'Feature Extraction Time (s)': [],
    'Inference Time (s)': [],
    'Memory Usage (MB)': [],
    'Detection Time (s)': []
}

# Fungsi pembantu evaluasi umum
def evaluate_matching_model(model_name, query_feats, dataset_feats, dataset_face_metadata, feat_extract_time, mem_used):
    t0 = time.time()
    # Evaluasi jarak Cosine secara matriks/ter-vektorisasi
    # query_feats: dict of {person: vector}
    # dataset_feats: array of shape (N_faces, dim)
    
    persons = ["A", "B", "C"]
    # Hitung semua jarak Cosine antara kueri dan wajah di dataset
    # Jarak Cosine = 1.0 - Cosine Similarity
    distances = {}
    for p in persons:
        q_feat = query_feats[p]
        q_norm = q_feat / (np.linalg.norm(q_feat) + 1e-10)
        
        # dataset_feats shape (N, dim)
        ds_norms = np.linalg.norm(dataset_feats, axis=1, keepdims=True) + 1e-10
        ds_normed = dataset_feats / ds_norms
        
        sims = np.dot(ds_normed, q_norm)
        sims = np.clip(sims, -1.0, 1.0)
        distances[p] = 1.0 - sims
        
    # Mencari threshold optimal dari 0.05 ke 0.95 dengan step 0.05
    thresholds = np.arange(0.05, 1.0, 0.05)
    best_f1 = -1
    best_thresh = 0.4
    best_metrics = {}
    
    # Struktur data target (ground truth)
    # Bentuk ground truth flat (1000 gambar * 3 orang = 3000 pasang)
    y_true = []
    for img_name in test_images:
        gt_img = ground_truth.get(img_name, {"contains_person_A": False, "contains_person_B": False, "contains_person_C": False})
        y_true.append(gt_img.get("contains_person_A", False))
        y_true.append(gt_img.get("contains_person_B", False))
        y_true.append(gt_img.get("contains_person_C", False))
    y_true = np.array(y_true, dtype=bool)
    
    # Lakukan grid search threshold
    for thresh in thresholds:
        # Lakukan prediksi untuk setiap gambar uji
        y_pred = []
        for img_name in test_images:
            # Cari indeks wajah-wajah yang terdeteksi di gambar ini
            indices = [i for i, meta in enumerate(dataset_face_metadata) if meta["img_name"] == img_name]
            
            for p in persons:
                if not indices:
                    # Tidak ada wajah terdeteksi
                    y_pred.append(False)
                else:
                    # Ambil jarak terkecil (wajah paling mirip) untuk kueri person p
                    min_dist = np.min(distances[p][indices])
                    y_pred.append(min_dist <= thresh)
                    
        y_pred = np.array(y_pred, dtype=bool)
        f1 = f1_score(y_true, y_pred, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_thresh = thresh
            best_metrics = {
                'Accuracy': accuracy_score(y_true, y_pred),
                'Precision': precision_score(y_true, y_pred, zero_division=0),
                'Recall': recall_score(y_true, y_pred, zero_division=0),
                'F1-Score': f1
            }
            
    infer_time = time.time() - t0
    
    # Catat ke tabel komparasi
    results['Model'].append(model_name)
    results['Accuracy'].append(best_metrics['Accuracy'])
    results['Precision'].append(best_metrics['Precision'])
    results['Recall'].append(best_metrics['Recall'])
    results['F1-Score'].append(best_metrics['F1-Score'])
    results['Best Threshold'].append(best_thresh)
    results['Feature Extraction Time (s)'].append(feat_extract_time)
    results['Inference Time (s)'].append(infer_time)
    results['Memory Usage (MB)'].append(mem_used)
    results['Detection Time (s)'].append(detection_time)
    
    print(f"--- {model_name} Evaluated ---")
    print(f"Best Threshold: {best_thresh:.2f}")
    print(f"Accuracy      : {best_metrics['Accuracy']:.4f}")
    print(f"F1-Score      : {best_metrics['F1-Score']:.4f}")
# Out:
# 2026-07-01 20:17:11,001 - INFO - Menginisialisasi detektor wajah MTCNN...
# Total Gambar Uji: 1000
# Total Gambar di Ground Truth: 1000
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
ke 810x1080 (max 1080px).
# 2026-07-01 20:19:05,360 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1204 ke 1080x812 (max 1080px).
# 2026-07-01 20:19:05,630 - INFO - Gambar resolusi tinggi di-downscale dari 1560x1040 ke 1080x720 (max 1080px).
# 2026-07-01 20:19:05,857 - INFO - Gambar resolusi tinggi di-downscale dari 1280x661 ke 1080x557 (max 1080px).
# 2026-07-01 20:19:06,066 - INFO - Gambar resolusi tinggi di-downscale dari 2928x1512 ke 1080x557 (max 1080px).
# 2026-07-01 20:19:06,230 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:06,441 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:06,650 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:07,257 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:07,602 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:07,991 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:08,314 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:08,637 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:08,970 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:09,301 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:09,613 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:10,126 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:10,463 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:10,735 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:10,981 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:11,889 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:12,117 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:12,496 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:12,645 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:12,827 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:13,013 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:13,215 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:13,462 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:13,630 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:13,966 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:14,419 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:14,654 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:14,843 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:15,080 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:15,275 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:15,490 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:15,698 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:15,902 - INFO - Gambar resolusi tinggi di-downscale dari 540x1170 ke 498x1080 (max 1080px).
# 2026-07-01 20:19:16,527 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:16,767 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:16,945 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:18,100 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:19:18,343 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:19,268 - INFO - Gambar resolusi tinggi di-downscale dari 708x1280 ke 597x1080 (max 1080px).
# 2026-07-01 20:19:19,900 - INFO - Gambar resolusi tinggi di-downscale dari 1156x521 ke 1080x486 (max 1080px).
# 2026-07-01 20:19:20,504 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:20,734 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:21,271 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:22,620 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:22,805 - INFO - Gambar resolusi tinggi di-downscale dari 1125x1150 ke 1056x1080 (max 1080px).
# 2026-07-01 20:19:23,098 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:24,505 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:24,675 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-07-01 20:19:25,151 - INFO - Gambar resolusi tinggi di-downscale dari 1125x385 ke 1080x369 (max 1080px).
# 2026-07-01 20:19:25,299 - INFO - Gambar resolusi tinggi di-downscale dari 1138x1600 ke 768x1080 (max 1080px).
# 2026-07-01 20:19:25,519 - INFO - Gambar resolusi tinggi di-downscale dari 1180x1377 ke 925x1080 (max 1080px).
# 2026-07-01 20:19:25,850 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:26,099 - INFO - Gambar resolusi tinggi di-downscale dari 719x1280 ke 606x1080 (max 1080px).
# 2026-07-01 20:19:26,277 - INFO - Gambar resolusi tinggi di-downscale dari 1202x1600 ke 811x1080 (max 1080px).
# 2026-07-01 20:19:26,807 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:27,068 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:27,303 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:27,819 - INFO - Gambar resolusi tinggi di-downscale dari 996x1280 ke 840x1080 (max 1080px).
# 2026-07-01 20:19:28,057 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:28,219 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-01 20:19:28,594 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:28,820 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:29,051 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-01 20:19:29,206 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-07-01 20:19:29,439 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-07-01 20:19:29,689 - INFO - Gambar resolusi tinggi di-downscale dari 1280x961 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:29,974 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:30,235 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:30,761 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-07-01 20:19:30,960 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-07-01 20:19:31,134 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-07-01 20:19:31,440 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:19:31,616 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:31,829 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:32,075 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:32,357 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:19:32,896 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1111 ke 1049x1080 (max 1080px).
# 2026-07-01 20:19:33,196 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:19:33,401 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-01 20:19:33,555 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-01 20:19:33,694 - INFO - Gambar resolusi tinggi di-downscale dari 576x1280 ke 486x1080 (max 1080px).
# 2026-07-01 20:19:33,888 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# ...
# 2026-07-01 20:21:08,816 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:09,146 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:09,384 - INFO - Gambar resolusi tinggi di-downscale dari 1389x534 ke 1080x415 (max 1080px).
# 2026-07-01 20:21:09,560 - INFO - Gambar resolusi tinggi di-downscale dari 1600x521 ke 1080x351 (max 1080px).
# 2026-07-01 20:21:09,696 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:09,908 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-07-01 20:21:10,333 - INFO - Gambar resolusi tinggi di-downscale dari 3936x2624 ke 1080x720 (max 1080px).
# 2026-07-01 20:21:10,651 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:10,842 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:11,163 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:11,479 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:11,852 - INFO - Gambar resolusi tinggi di-downscale dari 3127x4160 ke 811x1080 (max 1080px).
# 2026-07-01 20:21:12,113 - INFO - Gambar resolusi tinggi di-downscale dari 1204x1600 ke 812x1080 (max 1080px).
# 2026-07-01 20:21:12,353 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:12,590 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:12,836 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:13,166 - INFO - Gambar resolusi tinggi di-downscale dari 4000x3000 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:13,409 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:15,195 - INFO - Gambar resolusi tinggi di-downscale dari 4032x2268 ke 1080x607 (max 1080px).
# 2026-07-01 20:21:15,483 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-01 20:21:15,655 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-01 20:21:15,838 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:16,106 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:16,429 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:16,671 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:16,897 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1207 ke 1046x1080 (max 1080px).
# 2026-07-01 20:21:17,331 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:17,600 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-01 20:21:17,841 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:18,063 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:18,393 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-01 20:21:18,668 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-01 20:21:18,971 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:19,270 - INFO - Gambar resolusi tinggi di-downscale dari 1536x2730 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:19,505 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:19,707 - INFO - Gambar resolusi tinggi di-downscale dari 1600x930 ke 1080x627 (max 1080px).
# 2026-07-01 20:21:19,975 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-01 20:21:20,253 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:20,455 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:20,687 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:21,171 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:21,473 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 20:21:21,727 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:22,070 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:22,403 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:22,732 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:23,057 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:23,355 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:23,681 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:23,951 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:24,242 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-01 20:21:24,474 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-07-01 20:21:24,793 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:25,281 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:25,501 - INFO - Gambar resolusi tinggi di-downscale dari 1024x1536 ke 720x1080 (max 1080px).
# 2026-07-01 20:21:25,756 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:25,943 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1065 ke 1080x718 (max 1080px).
# 2026-07-01 20:21:26,174 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:26,428 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:26,669 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:26,909 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:27,147 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:27,339 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:27,576 - INFO - Gambar resolusi tinggi di-downscale dari 1280x854 ke 1080x720 (max 1080px).
# 2026-07-01 20:21:27,817 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:28,140 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:28,427 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:28,674 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:28,879 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:29,258 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:29,654 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:29,962 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:30,254 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:30,507 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:30,845 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:31,182 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:31,490 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:31,739 - INFO - Gambar resolusi tinggi di-downscale dari 591x1280 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:32,021 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:32,242 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:32,489 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 20:21:32,654 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:32,854 - INFO - Gambar resolusi tinggi di-downscale dari 1280x724 ke 1080x610 (max 1080px).
# 2026-07-01 20:21:33,164 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:33,428 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:33,672 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:33,904 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:34,152 - INFO - Gambar resolusi tinggi di-downscale dari 610x1356 ke 485x1080 (max 1080px).
# 2026-07-01 20:21:34,374 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1762 ke 1080x647 (max 1080px).
# 2026-07-01 20:21:34,587 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-01 20:21:34,806 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-01 20:21:35,087 - INFO - Gambar resolusi tinggi di-downscale dari 3840x2160 ke 1080x607 (max 1080px).
# 2026-07-01 20:21:35,282 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:35,500 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:35,781 - INFO - Gambar resolusi tinggi di-downscale dari 1600x853 ke 1080x575 (max 1080px).
# 2026-07-01 20:21:36,286 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:36,640 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:36,916 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:37,188 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:37,412 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1002 ke 1080x924 (max 1080px).
# 2026-07-01 20:21:37,804 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-01 20:21:38,074 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:38,524 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:38,821 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:39,042 - INFO - Gambar resolusi tinggi di-downscale dari 815x1180 ke 745x1080 (max 1080px).
# 2026-07-01 20:21:39,428 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:39,781 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:40,044 - INFO - Gambar resolusi tinggi di-downscale dari 1280x996 ke 1080x840 (max 1080px).
# 2026-07-01 20:21:40,340 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:40,737 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:41,001 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1272 ke 1080x1073 (max 1080px).
# 2026-07-01 20:21:41,479 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:41,769 - INFO - Gambar resolusi tinggi di-downscale dari 1600x894 ke 1080x603 (max 1080px).
# 2026-07-01 20:21:41,991 - INFO - Gambar resolusi tinggi di-downscale dari 871x1600 ke 587x1080 (max 1080px).
# 2026-07-01 20:21:42,392 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:42,673 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:43,086 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:43,336 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 20:21:43,541 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:43,867 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-01 20:21:44,247 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-01 20:21:44,658 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-01 20:21:44,973 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:45,391 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:45,652 - INFO - Gambar resolusi tinggi di-downscale dari 1280x782 ke 1080x659 (max 1080px).
# 2026-07-01 20:21:45,898 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:46,156 - INFO - Gambar resolusi tinggi di-downscale dari 3027x1638 ke 1080x584 (max 1080px).
# 2026-07-01 20:21:46,376 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:46,664 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 20:21:46,947 - INFO - Gambar resolusi tinggi di-downscale dari 583x1600 ke 393x1080 (max 1080px).
# 2026-07-01 20:21:47,096 - INFO - Gambar resolusi tinggi di-downscale dari 1296x892 ke 1080x743 (max 1080px).
# 2026-07-01 20:21:47,321 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:47,570 - INFO - Gambar resolusi tinggi di-downscale dari 2595x1638 ke 1080x681 (max 1080px).
# 2026-07-01 20:21:47,833 - INFO - Gambar resolusi tinggi di-downscale dari 2932x1760 ke 1080x648 (max 1080px).
# 2026-07-01 20:21:48,053 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:48,514 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:48,827 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:49,148 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:49,434 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:49,728 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:50,020 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:50,435 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:50,758 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:51,046 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 20:21:51,357 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# Berhasil mengumpulkan 6020 wajah dari 1000 gambar uji dalam 279.49 detik (deteksi+alignment).

# %% [markdown]
# ## 2. Metode Berbasis Geometri: Geometry-Based Landmarks
# Metode berbasis geometri mengidentifikasi wajah dengan mengukur jarak relatif antar landmark wajah utama seperti mata, hidung, dan mulut secara scale-invariant pada 6 jarak Euclidean berpasangan.

# %%
def extract_geometry_features(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    h_idx, w_idx = gray.shape
    
    def get_landmark_centroid(y_start, y_end, x_start, x_end):
        ys, ye = int(y_start * h_idx), int(y_end * h_idx)
        xs, xe = int(x_start * w_idx), int(x_end * w_idx)
        sub_img = gray[ys:ye, xs:xe]
        
        threshold = np.percentile(sub_img, 10)
        dark_pixels = np.argwhere(sub_img <= threshold)
        if len(dark_pixels) == 0:
            cy, cx = (ys + ye) / 2, (xs + xe) / 2
        else:
            cy = ys + np.mean(dark_pixels[:, 0])
            cx = xs + np.mean(dark_pixels[:, 1])
        return np.array([cx, cy])
        
    left_eye = get_landmark_centroid(0.2, 0.4, 0.2, 0.45)
    right_eye = get_landmark_centroid(0.2, 0.4, 0.55, 0.8)
    nose = get_landmark_centroid(0.45, 0.7, 0.4, 0.6)
    mouth = get_landmark_centroid(0.7, 0.95, 0.3, 0.7)
    
    dists = [
        np.linalg.norm(left_eye - right_eye),
        np.linalg.norm(left_eye - nose),
        np.linalg.norm(right_eye - nose),
        np.linalg.norm(left_eye - mouth),
        np.linalg.norm(right_eye - mouth),
        np.linalg.norm(nose - mouth)
    ]
    
    eye_dist = dists[0] if dists[0] > 0 else 1.0
    normalized_dists = [d / eye_dist for d in dists]
    return np.array(normalized_dists, dtype=np.float32)

print("Evaluasi Geometry-Based...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_geometry_features(face) for p, face in query_faces.items()}
dataset_feats = np.array([extract_geometry_features(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('Geometry-Based', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi Geometry-Based...
# --- Geometry-Based Evaluated ---
# Best Threshold: 0.05
# Accuracy      : 0.3450
# F1-Score      : 0.4087

# %% [markdown]
# ## 3. Metode Holistik: PCA (Eigenfaces)
# Principal Component Analysis (PCA) mereduksi dimensi gambar dari wajah ter-resize dengan memproyeksikannya ke eigenfaces berdimensi 150.

# %%
print("Evaluasi PCA (Eigenfaces)... ")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Flatten wajah ke grayscale
def flatten_gray_face(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    return gray.flatten().astype(np.float32) / 255.0

query_flat = np.array([flatten_gray_face(query_faces[p]) for p in ["A", "B", "C"]])
dataset_flat = np.array([flatten_gray_face(f["cropped_face"]) for f in dataset_faces])

# 2. Fit PCA pada kumpulan wajah dataset
n_components = min(150, len(dataset_faces))
pca = PCA(n_components=n_components, svd_solver='randomized', whiten=True)
pca.fit(dataset_flat)

# 3. Proyeksi
query_projected = pca.transform(query_flat)
dataset_projected = pca.transform(dataset_flat)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('PCA (Holistik)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi PCA (Eigenfaces)...
# --- PCA (Holistik) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.5423
# F1-Score      : 0.4421

# %% [markdown]
# ## 4. Metode Berbasis Fitur: LBP & HOG
# Mengekstrak fitur lokal menggunakan **Local Binary Pattern (LBP)** dan **Histogram of Oriented Gradients (HOG)**.

# %%
def extract_lbp_hist(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    n_bins = n_points + 2
    hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=(0, n_bins), density=True)
    return hist.astype(np.float32)

print("Evaluasi LBP...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_lbp_hist(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_lbp_hist(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

def extract_hog_vector(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    feat = hog(gray, orientations=8, pixels_per_cell=(8, 8),
               cells_per_block=(2, 2), visualize=False)
    return feat.astype(np.float32)

print("\nEvaluasi HOG...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_hog_vector(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_hog_vector(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('HOG (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP...
# --- LBP (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.25
# Accuracy      : 0.4413
# F1-Score      : 0.4256
#
# Evaluasi HOG...
# --- HOG (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.30
# Accuracy      : 0.5740
# F1-Score      : 0.4706

# %% [markdown]
# ## 5. Metode Hibrida: LBP + PCA
# Menggabungkan tekstur lokal dari LBP mentah dengan reduksi dimensi PCA (50 komponen).

# %%
def extract_raw_lbp(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    return lbp.ravel().astype(np.float32)

print("Evaluasi LBP + PCA (Hibrida)...")
mem_before = get_memory_usage()
t0 = time.time()

query_raw_lbp = np.array([extract_raw_lbp(query_faces[p]) for p in ["A", "B", "C"]])
dataset_raw_lbp = np.array([extract_raw_lbp(f["cropped_face"]) for f in dataset_faces])

n_components_hyb = min(50, len(dataset_faces))
pca_lbp = PCA(n_components=n_components_hyb, svd_solver='randomized', whiten=True)
pca_lbp.fit(dataset_raw_lbp)

query_projected = pca_lbp.transform(query_raw_lbp)
dataset_projected = pca_lbp.transform(dataset_raw_lbp)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP + PCA (Hibrida)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP + PCA (Hibrida)...
# --- LBP + PCA (Hibrida) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.4620
# F1-Score      : 0.4173

# %% [markdown]
# ## 6. Metode Deep Learning: Facenet (DeepFace)
# Mengekstrak embedding berdimensi 128 dari model Deep Learning Facenet (diload dari cache jika tersedia).

# %%
print("Evaluasi Facenet...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="Facenet", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    # Cek cache Facenet
    cached_found = False
    if img_name in preloaded_caches["Facenet"]:
        for cached_entry in preloaded_caches["Facenet"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        # Ekstraksi Baru dan simpan cache
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "Facenet")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["Facenet"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 100 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (Facenet)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi Facenet...
# --- DeepFace (Facenet) Evaluated ---
# Best Threshold: 0.40
# Accuracy      : 0.8743
# F1-Score      : 0.7351
# 198

# %% [markdown]
# ## 7. Metode Deep Learning: VGG-Face (DeepFace)
# Mengekstrak embedding berdimensi 2622 dari model Deep Learning VGG-Face (diload dari cache jika tersedia).

# %%
print("Evaluasi VGG-Face...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="VGG-Face", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["VGG-Face"]:
        for cached_entry in preloaded_caches["VGG-Face"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "VGG-Face")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["VGG-Face"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (VGG-Face)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi VGG-Face...
# --- DeepFace (VGG-Face) Evaluated ---
# Best Threshold: 0.60
# Accuracy      : 0.8943
# F1-Score      : 0.7466
# 305

# %% [markdown]
# ## 8. Metode Deep Learning: ArcFace (DeepFace)
# Mengekstrak embedding berdimensi 512 dari model Deep Learning ArcFace (diload dari cache jika tersedia). Ini adalah model yang digunakan oleh sistem utama GUI.

# %%
print("Evaluasi ArcFace...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="ArcFace", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["ArcFace"]:
        for cached_entry in preloaded_caches["ArcFace"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "ArcFace")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["ArcFace"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (ArcFace)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras setelah selesai pengujian
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi ArcFace...
# --- DeepFace (ArcFace) Evaluated ---
# Best Threshold: 0.65
# Accuracy      : 0.8610
# F1-Score      : 0.7114
# 404

# %% [markdown]
# ## 9. Visualisasi dan Perbandingan Kinerja
# Menampilkan tabel perbandingan DataFrame lengkap untuk kedelapan model, dan memvisualisasikan F1-Score, waktu eksekusi total (ekstraksi + pencocokan), serta tambahan penggunaan RAM.

# %%
df_results = pd.DataFrame(results)
print("\n--- Hasil Perbandingan Lengkap (8 Model) ---")
print(df_results.to_string(index=False))

# Tableau 10 color palette untuk visualisasi premium
colors = ['#4E79A7', '#F28E2B', '#E15759', '#76B7B2', '#59A14F', '#EDC948', '#B07AA1', '#FF9DA7']

plt.figure(figsize=(18, 6))

# 1. Plot F1-Score
plt.subplot(1, 3, 1)
bars1 = plt.bar(df_results['Model'], df_results['F1-Score'], color=colors[:len(df_results)])
plt.title('F1-Score Model (Tertinggi Terbaik)', fontsize=12, fontweight='bold')
plt.ylim(0, 1.15)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('F1-Score')
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.02, f"{yval:.2f}", ha='center', va='bottom', fontsize=9)

# 2. Plot Stacked Waktu Komputasi per Tahap (Deteksi + Ekstraksi + Inferensi)
plt.subplot(1, 3, 2)
det_times = df_results['Detection Time (s)']
feat_times = df_results['Feature Extraction Time (s)']
infer_times = df_results['Inference Time (s)']
plt.bar(df_results['Model'], det_times, color='#B07AA1', label='Deteksi & Alignment')
plt.bar(df_results['Model'], feat_times, bottom=det_times, color='#4E79A7', label='Ekstraksi Fitur')
plt.bar(df_results['Model'], infer_times, bottom=det_times + feat_times, color='#F28E2B', label='Inferensi/Matching')
total_time = det_times + feat_times + infer_times
plt.title('Waktu Komputasi per Tahap (detik)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Waktu (detik)')
plt.legend(fontsize=7, loc='upper left')
for i, total in enumerate(total_time):
    plt.text(i, total + (total * 0.02) + 0.05, f"{total:.2f}s", ha='center', va='bottom', fontsize=9)

# 3. Plot Memory Usage
plt.subplot(1, 3, 3)
bars3 = plt.bar(df_results['Model'], df_results['Memory Usage (MB)'], color=colors[:len(df_results)])
plt.title('Penggunaan Memori Tambahan (MB)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Memori (MB)')
for bar in bars3:
    yval = bar.get_height()
    # Jaga formatting
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.1, f"{yval:.1f} MB", ha='center', va='bottom', fontsize=9)

plt.tight_layout()
assets_dir = os.path.join(project_root, "assets")
os.makedirs(assets_dir, exist_ok=True)
plt.savefig(os.path.join(assets_dir, "perbandingan_kinerja_mtcnn.png"), dpi=300, bbox_inches="tight")
plt.show()
# Out:
# --- Hasil Perbandingan Lengkap (8 Model) ---
#                Model  Accuracy  Precision   Recall  F1-Score  Best Threshold  Feature Extraction Time (s)  Inference Time (s)  Memory Usage (MB)  Detection Time (s)
#       Geometry-Based  0.345000   0.259557 0.960396  0.408667            0.05                     1.698522            6.202859           0.781250           279.48695
#       PCA (Holistik)  0.542333   0.310148 0.769448  0.442097            0.95                     4.007720            6.422600         292.859375           279.48695
# LBP (Berbasis Fitur)  0.441333   0.280868 0.878359  0.425634            0.25                    11.091806            6.949630           0.597656           279.48695
# HOG (Berbasis Fitur)  0.574000   0.332748 0.803395  0.470588            0.30                    15.903175            6.887330         113.621094           279.48695
#  LBP + PCA (Hibrida)  0.462000   0.280175 0.817539  0.417329            0.95                     9.856407            6.657027         310.414062           279.48695
#   DeepFace (Facenet)  0.874333   0.730447 0.739745  0.735067            0.40                  1285.664948            6.300534           0.000000           279.48695
#  DeepFace (VGG-Face)  0.894333   0.858456 0.660537  0.746603            0.60                  1349.625866            6.669426        1433.906250           279.48695
#   DeepFace (ArcFace)  0.861000   0.696477 0.727016  0.711419            0.65                  1131.002321            6.673521           0.000000           279.48695

# %%
DETECTOR_TYPE = "mtcnn"

# %% [markdown]
# ## 10. Uji Skalabilitas: Waktu Pemrosesan vs Jumlah Data
#
# Bagian ini menguji ketiga model Deep Learning (**ArcFace**, **Facenet**, **VGG-Face**) pada lima ukuran dataset yang berbeda: 100, 300, 500, 700, dan 1000 gambar (`test_case_100` s.d. `test_case_700`, serta `test_case` untuk 1000 gambar). Untuk setiap ukuran data, dicatat waktu **deteksi & alignment wajah** serta waktu **ekstraksi fitur** per model, tanpa menggunakan cache, agar waktu yang terukur murni mencerminkan biaya komputasi untuk jumlah data tersebut.

# %%
SCALING_SIZES = [100, 300, 500, 700, 1000]
SCALING_MODELS = ["ArcFace", "Facenet", "VGG-Face"]

def get_scaling_dir(size):
    if size == 1000:
        return os.path.join(TESTSET_DIR, "test_case")
    return os.path.join(TESTSET_DIR, f"test_case_{size}")

scaling_results = {
    "Data Size": [],
    "Model": [],
    "Num Images": [],
    "Num Faces Detected": [],
    "Detection Time (s)": [],
    "Feature Extraction Time (s)": [],
    "Total Time (s)": []
}

# %%
import gc

for size in SCALING_SIZES:
    img_dir = get_scaling_dir(size)
    img_files = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    print(f"\n=== Ukuran Data: {size} ({len(img_files)} gambar ditemukan di {os.path.basename(img_dir)}) ===")

    # Deteksi & alignment wajah sekali per ukuran data, dipakai bersama oleh ketiga model
    t0 = time.time()
    scaling_faces = []
    for img_name in img_files:
        img_path = os.path.join(img_dir, img_name)
        rois = detector.detect_and_crop(img_path)
        for roi in rois:
            scaling_faces.append(roi["cropped_face"])
    det_time = time.time() - t0
    print(f"Deteksi: {len(scaling_faces)} wajah dalam {det_time:.2f} detik")

    for model_name in SCALING_MODELS:
        t0 = time.time()
        for face_img in scaling_faces:
            _ = extract_deepface_embedding(face_img, model_name)
        feat_time = time.time() - t0

        scaling_results["Data Size"].append(size)
        scaling_results["Model"].append(model_name)
        scaling_results["Num Images"].append(len(img_files))
        scaling_results["Num Faces Detected"].append(len(scaling_faces))
        scaling_results["Detection Time (s)"].append(det_time)
        scaling_results["Feature Extraction Time (s)"].append(feat_time)
        scaling_results["Total Time (s)"].append(det_time + feat_time)

        print(f"  {model_name}: ekstraksi {feat_time:.2f} detik (total {det_time + feat_time:.2f} detik)")
        gc.collect()

    del scaling_faces
    gc.collect()

import tensorflow as tf
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 2026-07-01 21:26:15,056 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# === Ukuran Data: 100 (100 gambar ditemukan di test_case_100) ===
# 2026-07-01 21:26:15,487 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:15,864 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:16,271 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:16,643 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:16,974 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:17,281 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:17,595 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:17,942 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:18,585 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:19,215 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:19,756 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:20,234 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:20,767 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:21,191 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:21,533 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:21,891 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:22,276 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:22,599 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:24,326 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 21:26:27,484 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-01 21:26:28,896 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 21:26:29,307 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 21:26:29,602 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:29,982 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:30,303 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:30,844 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:31,395 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:32,177 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:32,932 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:33,604 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:34,282 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:26:35,059 - INFO - Gambar resolusi tinggi di-downscale dari 1152x768 ke 1080x720 (max 1080px).
# 2026-07-01 21:26:35,365 - INFO - Gambar resolusi tinggi di-downscale dari 588x1280 ke 496x1080 (max 1080px).
# 2026-07-01 21:26:35,600 - INFO - Gambar resolusi tinggi di-downscale dari 640x1280 ke 540x1080 (max 1080px).
# 2026-07-01 21:26:36,761 - INFO - Gambar resolusi tinggi di-downscale dari 682x1280 ke 575x1080 (max 1080px).
# 2026-07-01 21:26:37,212 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-01 21:26:37,669 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-01 21:26:39,982 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-01 21:26:40,696 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-01 21:26:41,363 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-07-01 21:26:41,926 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-01 21:26:42,887 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-01 21:26:43,197 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:46,883 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 21:26:47,378 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-01 21:26:47,708 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-01 21:26:48,020 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-01 21:26:51,064 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-01 21:26:51,465 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:51,777 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-07-01 21:26:52,131 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-07-01 21:26:52,644 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:52,914 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:53,202 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:53,491 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 21:26:53,790 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1202 ke 1080x811 (max 1080px).
# 2026-07-01 21:26:54,063 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 21:26:54,301 - INFO - Gambar resolusi tinggi di-downscale dari 872x1160 ke 811x1080 (max 1080px).
# 2026-07-01 21:26:54,537 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# Deteksi: 570 wajah dalam 39.69 detik
#   ArcFace: ekstraksi 132.05 detik (total 171.74 detik)
#   Facenet: ekstraksi 114.26 detik (total 153.95 detik)
# 2026-07-01 21:32:57,803 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
#   VGG-Face: ekstraksi 116.02 detik (total 155.71 detik)
#
# === Ukuran Data: 300 (300 gambar ditemukan di test_case_300) ===
# 2026-07-01 21:32:58,114 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:32:58,421 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:32:58,735 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:32:59,036 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:32:59,352 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:32:59,653 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:32:59,977 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:00,309 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:00,622 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:00,935 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:01,257 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:01,571 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:01,912 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:02,261 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:02,596 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:02,926 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:03,246 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:03,549 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:05,208 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 21:33:07,997 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-01 21:33:08,987 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 21:33:09,393 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-01 21:33:09,707 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:10,107 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:10,416 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:10,985 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:11,531 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:12,358 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:13,012 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:13,482 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:13,971 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-01 21:33:14,527 - INFO - Gambar resolusi tinggi di-downscale dari 1152x768 ke 1080x720 (max 1080px).
# 2026-07-01 21:33:14,848 - INFO - Gambar resolusi tinggi di-downscale dari 588x1280 ke 496x1080 (max 1080px).
# 2026-07-01 21:33:15,086 - INFO - Gambar resolusi tinggi di-downscale dari 640x1280 ke 540x1080 (max 1080px).
# 2026-07-01 21:33:15,780 - INFO - Gambar resolusi tinggi di-downscale dari 682x1280 ke 575x1080 (max 1080px).
# 2026-07-01 21:33:16,051 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-01 21:33:16,285 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-01 21:33:17,593 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-01 21:33:18,039 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-01 21:33:18,576 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-07-01 21:33:18,912 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-01 21:33:19,754 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-01 21:33:20,027 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:23,504 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 21:33:24,255 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-01 21:33:24,760 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-01 21:33:25,146 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-01 21:33:28,782 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-01 21:33:29,292 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 21:33:29,718 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-07-01 21:33:30,078 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-07-01 21:33:30,591 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-01 21:33
- INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:40,394 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:40,680 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 23:31:40,912 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:41,205 - INFO - Gambar resolusi tinggi di-downscale dari 1280x854 ke 1080x720 (max 1080px).
# 2026-07-01 23:31:41,493 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 23:31:41,851 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:42,203 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:42,544 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 23:31:42,780 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 23:31:43,213 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:43,682 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:44,009 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:44,339 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:44,638 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:45,081 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:45,555 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:45,995 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:46,373 - INFO - Gambar resolusi tinggi di-downscale dari 591x1280 ke 498x1080 (max 1080px).
# 2026-07-01 23:31:46,732 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:47,034 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:47,352 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-01 23:31:47,559 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-01 23:31:47,775 - INFO - Gambar resolusi tinggi di-downscale dari 1280x724 ke 1080x610 (max 1080px).
# 2026-07-01 23:31:48,124 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:48,481 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:48,801 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:49,108 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:49,443 - INFO - Gambar resolusi tinggi di-downscale dari 610x1356 ke 485x1080 (max 1080px).
# 2026-07-01 23:31:49,746 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1762 ke 1080x647 (max 1080px).
# 2026-07-01 23:31:50,038 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-01 23:31:50,324 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-01 23:31:50,650 - INFO - Gambar resolusi tinggi di-downscale dari 3840x2160 ke 1080x607 (max 1080px).
# 2026-07-01 23:31:50,891 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-01 23:31:51,170 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:51,536 - INFO - Gambar resolusi tinggi di-downscale dari 1600x853 ke 1080x575 (max 1080px).
# 2026-07-01 23:31:52,150 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:52,545 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:52,921 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:53,270 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 23:31:53,546 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1002 ke 1080x924 (max 1080px).
# 2026-07-01 23:31:53,913 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-01 23:31:54,164 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:54,581 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:54,903 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 23:31:55,109 - INFO - Gambar resolusi tinggi di-downscale dari 815x1180 ke 745x1080 (max 1080px).
# 2026-07-01 23:31:55,524 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:55,913 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:56,225 - INFO - Gambar resolusi tinggi di-downscale dari 1280x996 ke 1080x840 (max 1080px).
# 2026-07-01 23:31:56,547 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:56,960 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:57,248 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1272 ke 1080x1073 (max 1080px).
# 2026-07-01 23:31:57,801 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:58,137 - INFO - Gambar resolusi tinggi di-downscale dari 1600x894 ke 1080x603 (max 1080px).
# 2026-07-01 23:31:58,411 - INFO - Gambar resolusi tinggi di-downscale dari 871x1600 ke 587x1080 (max 1080px).
# 2026-07-01 23:31:58,877 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:59,182 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:31:59,586 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-07-01 23:31:59,860 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-01 23:32:00,108 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:32:00,478 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-01 23:32:00,889 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-01 23:32:01,316 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-01 23:32:01,661 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:02,092 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-01 23:32:02,396 - INFO - Gambar resolusi tinggi di-downscale dari 1280x782 ke 1080x659 (max 1080px).
# 2026-07-01 23:32:02,680 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:03,010 - INFO - Gambar resolusi tinggi di-downscale dari 3027x1638 ke 1080x584 (max 1080px).
# 2026-07-01 23:32:03,306 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:32:03,685 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-01 23:32:04,058 - INFO - Gambar resolusi tinggi di-downscale dari 583x1600 ke 393x1080 (max 1080px).
# 2026-07-01 23:32:04,241 - INFO - Gambar resolusi tinggi di-downscale dari 1296x892 ke 1080x743 (max 1080px).
# 2026-07-01 23:32:04,518 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:04,803 - INFO - Gambar resolusi tinggi di-downscale dari 2595x1638 ke 1080x681 (max 1080px).
# 2026-07-01 23:32:05,133 - INFO - Gambar resolusi tinggi di-downscale dari 2932x1760 ke 1080x648 (max 1080px).
# 2026-07-01 23:32:05,389 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:05,805 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:06,171 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:06,489 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:06,809 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:07,158 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:07,480 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:07,848 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:08,271 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:08,610 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-01 23:32:08,961 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# Deteksi: 6020 wajah dalam 341.39 detik
#   ArcFace: ekstraksi 1346.50 detik (total 1687.89 detik)
#   Facenet: ekstraksi 1142.77 detik (total 1484.16 detik)
#   VGG-Face: ekstraksi 1620.66 detik (total 1962.05 detik)
# 107

# %%
df_scaling = pd.DataFrame(scaling_results)
print("\n--- Hasil Uji Skalabilitas (Waktu vs Jumlah Data) ---")
print(df_scaling.to_string(index=False))

scaling_colors = {'ArcFace': '#4E79A7', 'Facenet': '#F28E2B', 'VGG-Face': '#E15759'}

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
for model_name in SCALING_MODELS:
    subset = df_scaling[df_scaling["Model"] == model_name]
    plt.plot(subset["Data Size"], subset["Total Time (s)"], marker='o', label=model_name, color=scaling_colors[model_name])
plt.title("Waktu Total (Deteksi + Ekstraksi) vs Jumlah Data", fontsize=12, fontweight="bold")
plt.xlabel("Jumlah Gambar")
plt.ylabel("Waktu Total (detik)")
plt.legend()
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
for model_name in SCALING_MODELS:
    subset = df_scaling[df_scaling["Model"] == model_name]
    plt.plot(subset["Data Size"], subset["Feature Extraction Time (s)"], marker='o', label=model_name, color=scaling_colors[model_name])
plt.title("Waktu Ekstraksi Fitur vs Jumlah Data", fontsize=12, fontweight="bold")
plt.xlabel("Jumlah Gambar")
plt.ylabel("Waktu Ekstraksi (detik)")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
assets_dir = os.path.join(project_root, "assets")
os.makedirs(assets_dir, exist_ok=True)
plt.savefig(os.path.join(assets_dir, f"uji_skalabilitas_{DETECTOR_TYPE}.png"), dpi=300, bbox_inches="tight")
plt.show()
# Out:
# --- Hasil Uji Skalabilitas (Waktu vs Jumlah Data) ---
#  Data Size    Model  Num Images  Num Faces Detected  Detection Time (s)  Feature Extraction Time (s)  Total Time (s)
#        100  ArcFace         100                 570           39.694456                   132.048711      171.743166
#        100  Facenet         100                 570           39.694456                   114.259325      153.953781
#        100 VGG-Face         100                 570           39.694456                   116.017421      155.711876
#        300  ArcFace         300                2360          104.329924                   407.960043      512.289967
#        300  Facenet         300                2360          104.329924                   521.202161      625.532085
#        300 VGG-Face         300                2360          104.329924                   574.814339      679.144263
#        500  ArcFace         500                3134          167.250384                   560.384227      727.634611
#        500  Facenet         500                3134          167.250384                   625.849334      793.099719
#        500 VGG-Face         500                3134          167.250384                   688.896389      856.146773
#        700  ArcFace         700                4626          229.317283                   861.586375     1090.903658
#        700  Facenet         700                4626          229.317283                  1023.579026     1252.896309
#        700 VGG-Face         700                4626          229.317283                  1042.588632     1271.905915
#       1000  ArcFace        1000                6020          341.385515                  1346.499495     1687.885010
#       1000  Facenet        1000                6020          341.385515                  1142.770310     1484.155825
#       1000 VGG-Face        1000                6020          341.385515                  1620.661367     1962.046882
