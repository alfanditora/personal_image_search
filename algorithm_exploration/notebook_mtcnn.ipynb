# %% [markdown]
# # Eksplorasi Algoritma Face Recognition (MTCNN Detector)
#
# Notebook ini bertujuan untuk membandingkan delapan metode pengenalan wajah sesuai dengan uji yang dilakukan di sistem GUI:
# 1. **Geometry-Based (Geometric Landmarks)**
# 2. **PCA (Holistik)**
# 3. **LBP (Berbasis Fitur)**
# 4. **HOG (Berbasis Fitur)**
# 5. **LBP + PCA (Hibrida)**
# 6. **DeepFace - Facenet (Deep Learning)**
# 7. **DeepFace - VGG-Face (Deep Learning)**
# 8. **DeepFace - ArcFace (Deep Learning)**
#
# Pengujian dilakukan dengan mencocokkan foto selfie kueri (Person A, B, C) dengan seluruh 1000 gambar uji di dataset, menggunakan metode pencocokan jarak Cosine langsung (tanpa SVM) seperti pada sistem GUI. Evaluasi akan mencari threshold optimal untuk masing-masing model untuk perbandingan yang adil.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import time
import os
import psutil
import sys
import json
import hashlib
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from skimage.feature import local_binary_pattern, hog
from deepface import DeepFace
import pandas as pd

# Fungsi untuk mendapatkan penggunaan memori saat ini dalam MB
def get_memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)

# Menemukan project root
possible_roots = [
    os.path.abspath("."),
    os.path.abspath(".."),
    os.path.abspath("../..")
]
project_root = None
for root in possible_roots:
    if os.path.exists(os.path.join(root, "core")) and os.path.exists(os.path.join(root, "cache_io")):
        project_root = root
        break
if project_root is None:
    project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(f"Project root diatur ke: {project_root}")

from src.core.detector import FaceDetector
from src.cache_io.cache_handler import CacheHandler
# Out:
# WARNING:tensorflow:From c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Project root diatur ke: c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search

# %% [markdown]
# ## 1. Persiapan Dataset & Integrasi Cache
# Memuat dataset pengujian dari `D:\dataset\testset`, foto kueri dari `queries/`, ground truth dari `ground_truth.json`, dan inisialisasi model cache terpisah untuk masing-masing model Deep Learning menggunakan `CacheHandler` dari `cache_io`.

# %%
TESTSET_DIR = "D:/dataset/testset"
TEST_IMAGES_DIR = os.path.join(TESTSET_DIR, "test_case")
QUERIES_DIR = os.path.join(TESTSET_DIR, "queries")
GROUND_TRUTH_PATH = os.path.join(TESTSET_DIR, "ground_truth.json")

# 1. Load Ground Truth
with open(GROUND_TRUTH_PATH, "r", encoding="utf-8") as f:
    ground_truth = json.load(f)

test_images = [f for f in os.listdir(TEST_IMAGES_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
LIMIT_IMAGES = None  # Ganti dengan angka (misal 100) untuk pengujian cepat, atau None untuk seluruh gambar
if LIMIT_IMAGES is not None:
    test_images = test_images[:LIMIT_IMAGES]
print(f"Total Gambar Uji: {len(test_images)}")
print(f"Total Gambar di Ground Truth: {len(ground_truth)}")

# 2. Inisialisasi Face Detector
detector = FaceDetector("mtcnn")

# 3. Subclass CacheHandler untuk menentukan direktori cache secara dinamis per model
class ModelCacheHandler(CacheHandler):
    def __init__(self, folder_input_path: str, model_name: str):
        super().__init__(folder_input_path)
        self.model_name = model_name.lower()
        self.cache_dir = os.path.join(self.folder_input_path, f".face_cache_mtcnn_{self.model_name}")
        os.makedirs(self.cache_dir, exist_ok=True)

    def cache_exists(self, file_name: str, bbox: tuple) -> bool:
        bbox_str = f"_{bbox[0]}_{bbox[1]}_{bbox[2]}_{bbox[3]}"
        unique_id = hashlib.md5((file_name + bbox_str).encode('utf-8')).hexdigest()
        cache_file_path = os.path.join(self.cache_dir, f"{unique_id}.json")
        return os.path.exists(cache_file_path)

# 4. Load Preloaded Cache untuk efisiensi eksekusi notebook
models_dl = ["ArcFace", "Facenet", "VGG-Face"]
handlers = {model: ModelCacheHandler(TEST_IMAGES_DIR, model) for model in models_dl}
preloaded_caches = {}

for model in models_dl:
    print(f"Memuat cache untuk model {model}...")
    cache_list = handlers[model].muat_seluruh_cache()
    model_cache = {}
    for entry in cache_list:
        img_name = entry["file_name"]
        if img_name not in model_cache:
            model_cache[img_name] = []
        model_cache[img_name].append(entry)
    preloaded_caches[model] = model_cache

# 5. Helper untuk memuat wajah (face ROIs) — selalu menggunakan detector untuk alignment konsisten
def get_face_rois(img_path, detector):
    # Selalu jalankan detector.detect_and_crop agar affine alignment 5-titik diterapkan
    # secara konsisten di setiap run, tanpa bergantung pada cache bbox yang mungkin
    # dihasilkan oleh detector berbeda atau tanpa alignment.
    return detector.detect_and_crop(img_path)

def extract_deepface_embedding(face_img, model_name):
    if len(face_img.shape) == 2:
        face_img = cv2.cvtColor(face_img, cv2.COLOR_GRAY2BGR)
    elif face_img.shape[2] == 4:
        face_img = face_img[:, :, :3]
    # Downscale check for safe preprocessing
    h_f, w_f = face_img.shape[:2]
    if max(h_f, w_f) > 1080:
        scale_f = 1080.0 / max(h_f, w_f)
        face_img = cv2.resize(face_img, (int(w_f * scale_f), int(h_f * scale_f)), interpolation=cv2.INTER_AREA)
    objs = DeepFace.represent(
        img_path=face_img,
        model_name=model_name,
        enforce_detection=False,
        detector_backend="skip"
    )
    return np.array(objs[0]['embedding'], dtype=np.float32)

# 6. Ekstraksi Wajah untuk Kueri
queries = {
    "A": os.path.join(QUERIES_DIR, "selfie_A.jpeg"),
    "B": os.path.join(QUERIES_DIR, "selfie_B.jpg"),
    "C": os.path.join(QUERIES_DIR, "selfie_C.jpg")
}
query_faces = {}
for person, path in queries.items():
    faces = detector.detect_and_crop(path)
    if faces:
        query_faces[person] = faces[0]["cropped_face"]
        print(f"Wajah kueri Person {person} berhasil dideteksi.")
    else:
        raise RuntimeError(f"Gagal mendeteksi wajah pada kueri: {path}")

# 7. Kumpulkan semua wajah terdeteksi dari dataset gambar uji (Face Cropping tunggal untuk keadilan evaluasi)
print("Mengumpulkan wajah dari dataset gambar uji...")
t0 = time.time()
dataset_faces = [] # list of dict: {"img_name": str, "cropped_face": np.ndarray, "bbox": tuple}
for img_name in test_images:
    img_path = os.path.join(TEST_IMAGES_DIR, img_name)
    rois = get_face_rois(img_path, detector)
    for roi in rois:
        dataset_faces.append({
            "img_name": img_name,
            "cropped_face": roi["cropped_face"],
            "bbox": roi["bbox"]
        })
detection_time = time.time() - t0
print(f"Berhasil mengumpulkan {len(dataset_faces)} wajah dari {len(test_images)} gambar uji dalam {detection_time:.2f} detik (deteksi+alignment).")

# Penampung hasil komparasi
results = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-Score': [],
    'Best Threshold': [],
    'Feature Extraction Time (s)': [],
    'Inference Time (s)': [],
    'Memory Usage (MB)': [],
    'Detection Time (s)': []
}

# Fungsi pembantu evaluasi umum
def evaluate_matching_model(model_name, query_feats, dataset_feats, dataset_face_metadata, feat_extract_time, mem_used):
    t0 = time.time()
    # Evaluasi jarak Cosine secara matriks/ter-vektorisasi
    # query_feats: dict of {person: vector}
    # dataset_feats: array of shape (N_faces, dim)
    
    persons = ["A", "B", "C"]
    # Hitung semua jarak Cosine antara kueri dan wajah di dataset
    # Jarak Cosine = 1.0 - Cosine Similarity
    distances = {}
    for p in persons:
        q_feat = query_feats[p]
        q_norm = q_feat / (np.linalg.norm(q_feat) + 1e-10)
        
        # dataset_feats shape (N, dim)
        ds_norms = np.linalg.norm(dataset_feats, axis=1, keepdims=True) + 1e-10
        ds_normed = dataset_feats / ds_norms
        
        sims = np.dot(ds_normed, q_norm)
        sims = np.clip(sims, -1.0, 1.0)
        distances[p] = 1.0 - sims
        
    # Mencari threshold optimal dari 0.05 ke 0.95 dengan step 0.05
    thresholds = np.arange(0.05, 1.0, 0.05)
    best_f1 = -1
    best_thresh = 0.4
    best_metrics = {}
    
    # Struktur data target (ground truth)
    # Bentuk ground truth flat (1000 gambar * 3 orang = 3000 pasang)
    y_true = []
    for img_name in test_images:
        gt_img = ground_truth.get(img_name, {"contains_person_A": False, "contains_person_B": False, "contains_person_C": False})
        y_true.append(gt_img.get("contains_person_A", False))
        y_true.append(gt_img.get("contains_person_B", False))
        y_true.append(gt_img.get("contains_person_C", False))
    y_true = np.array(y_true, dtype=bool)
    
    # Lakukan grid search threshold
    for thresh in thresholds:
        # Lakukan prediksi untuk setiap gambar uji
        y_pred = []
        for img_name in test_images:
            # Cari indeks wajah-wajah yang terdeteksi di gambar ini
            indices = [i for i, meta in enumerate(dataset_face_metadata) if meta["img_name"] == img_name]
            
            for p in persons:
                if not indices:
                    # Tidak ada wajah terdeteksi
                    y_pred.append(False)
                else:
                    # Ambil jarak terkecil (wajah paling mirip) untuk kueri person p
                    min_dist = np.min(distances[p][indices])
                    y_pred.append(min_dist <= thresh)
                    
        y_pred = np.array(y_pred, dtype=bool)
        f1 = f1_score(y_true, y_pred, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_thresh = thresh
            best_metrics = {
                'Accuracy': accuracy_score(y_true, y_pred),
                'Precision': precision_score(y_true, y_pred, zero_division=0),
                'Recall': recall_score(y_true, y_pred, zero_division=0),
                'F1-Score': f1
            }
            
    infer_time = time.time() - t0
    
    # Catat ke tabel komparasi
    results['Model'].append(model_name)
    results['Accuracy'].append(best_metrics['Accuracy'])
    results['Precision'].append(best_metrics['Precision'])
    results['Recall'].append(best_metrics['Recall'])
    results['F1-Score'].append(best_metrics['F1-Score'])
    results['Best Threshold'].append(best_thresh)
    results['Feature Extraction Time (s)'].append(feat_extract_time)
    results['Inference Time (s)'].append(infer_time)
    results['Memory Usage (MB)'].append(mem_used)
    results['Detection Time (s)'].append(detection_time)
    
    print(f"--- {model_name} Evaluated ---")
    print(f"Best Threshold: {best_thresh:.2f}")
    print(f"Accuracy      : {best_metrics['Accuracy']:.4f}")
    print(f"F1-Score      : {best_metrics['F1-Score']:.4f}")
# Out:
# 2026-06-21 23:02:47,735 - INFO - Menginisialisasi detektor wajah MTCNN...
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# Exception ignored in: <_io.BufferedReader>
# Traceback (most recent call last):
#   File "c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search\venv\Lib\site-packages\lz4\frame\__init__.py", line 753, in flush
#     self._fp.flush()
# ValueError: I/O operation on closed file.
# 2026-06-21 23:02:47,920 - INFO - Detektor wajah MTCNN berhasil diinisialisasi.
# 2026-06-21 23:02:47,921 - INFO - Direktori cache Zero-DB siap di: D:\dataset\testset\test_case\.face_cache
# 2026-06-21 23:02:47,922 - INFO - Direktori cache Zero-DB siap di: D:\dataset\testset\test_case\.face_cache
# 2026-06-21 23:02:47,923 - INFO - Direktori cache Zero-DB siap di: D:\dataset\testset\test_case\.face_cache
# 2026-06-21 23:02:47,924 - INFO - Menemukan 0 berkas cache di D:\dataset\testset\test_case\.face_cache_mtcnn_arcface. Memulai pemuatan...
# 2026-06-21 23:02:47,925 - INFO - Berhasil memuat 0 data cache wajah yang valid ke dalam RAM.
# 2026-06-21 23:02:47,925 - INFO - Menemukan 0 berkas cache di D:\dataset\testset\test_case\.face_cache_mtcnn_facenet. Memulai pemuatan...
# 2026-06-21 23:02:47,926 - INFO - Berhasil memuat 0 data cache wajah yang valid ke dalam RAM.
# 2026-06-21 23:02:47,927 - INFO - Menemukan 0 berkas cache di D:\dataset\testset\test_case\.face_cache_mtcnn_vgg-face. Memulai pemuatan...
# 2026-06-21 23:02:47,927 - INFO - Berhasil memuat 0 data cache wajah yang valid ke dalam RAM.
# Total Gambar Uji: 1000
# Total Gambar di Ground Truth: 1000
# Memuat cache untuk model ArcFace...
# Memuat cache untuk model Facenet...
# Memuat cache untuk model VGG-Face...
# 2026-06-21 23:02:47,956 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# Wajah kueri Person A berhasil dideteksi.
# Wajah kueri Person B berhasil dideteksi.
# 2026-06-21 23:02:48,535 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# Wajah kueri Person C berhasil dideteksi.
# Mengumpulkan wajah dari dataset gambar uji...
# 2026-06-21 23:02:48,831 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:49,161 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:49,450 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:49,743 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:50,022 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:50,307 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:50,575 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:50,860 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:51,145 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:51,447 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:51,752 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:52,047 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:52,326 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:52,612 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:52,916 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:53,225 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:53,504 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:53,766 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:02:55,100 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:02:57,249 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-06-21 23:02:58,083 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:02:58,330 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:02:58,561 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:02:58,868 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:02:59,111 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:02:59,535 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:02:59,915 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:00,608 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:01,095 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:01,479 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:01,841 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:02,305 - INFO - Gambar resolusi tinggi di-downscale dari 1152x768 ke 1080x720 (max 1080px).
# 2026-06-21 23:03:02,557 - INFO - Gambar resolusi tinggi di-downscale dari 588x1280 ke 496x1080 (max 1080px).
# 2026-06-21 23:03:02,735 - INFO - Gambar resolusi tinggi di-downscale dari 640x1280 ke 540x1080 (max 1080px).
# 2026-06-21 23:03:03,303 - INFO - Gambar resolusi tinggi di-downscale dari 682x1280 ke 575x1080 (max 1080px).
# 2026-06-21 23:03:03,515 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-06-21 23:03:03,709 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-06-21 23:03:04,767 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-06-21 23:03:05,164 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-06-21 23:03:05,513 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-06-21 23:03:05,751 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:03:06,390 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-21 23:03:06,577 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:08,741 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:09,055 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-06-21 23:03:09,285 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-06-21 23:03:09,499 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-06-21 23:03:11,729 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-06-21 23:03:12,032 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:12,277 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-21 23:03:12,570 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-21 23:03:12,972 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:13,216 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:13,481 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:13,736 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:14,006 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1202 ke 1080x811 (max 1080px).
# 2026-06-21 23:03:14,250 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:14,487 - INFO - Gambar resolusi tinggi di-downscale dari 872x1160 ke 811x1080 (max 1080px).
# 2026-06-21 23:03:14,709 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:14,902 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:03:15,078 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:03:15,239 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:03:15,399 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:03:15,567 - INFO - Gambar resolusi tinggi di-downscale dari 896x1280 ke 756x1080 (max 1080px).
# 2026-06-21 23:03:15,825 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1261 ke 924x1080 (max 1080px).
# 2026-06-21 23:03:16,102 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1264 ke 922x1080 (max 1080px).
# 2026-06-21 23:03:16,355 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-06-21 23:03:16,603 - INFO - Gambar resolusi tinggi di-downscale dari 1066x1599 ke 720x1080 (max 1080px).
# 2026-06-21 23:03:16,882 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:17,247 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:17,458 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:17,734 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:18,058 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:18,345 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:18,618 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:18,883 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:19,165 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:19,413 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:19,672 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:19,948 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:20,230 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:20,564 - INFO - Gambar resolusi tinggi di-downscale dari 1197x1600 ke 807x1080 (max 1080px).
# 2026-06-21 23:03:20,828 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1197 ke 1080x807 (max 1080px).
# 2026-06-21 23:03:21,127 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1197 ke 1080x807 (max 1080px).
# 2026-06-21 23:03:21,386 - INFO - Gambar resolusi tinggi di-downscale dari 1197x1600 ke 807x1080 (max 1080px).
# 2026-06-21 23:03:21,645 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:21,889 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:22,183 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:22,549 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-21 23:03:22,919 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-21 23:03:23,120 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-21 23:03:23,322 - INFO - Gambar resolusi tinggi di-downscale dari 1477x1108 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:23,632 - INFO - Gambar resolusi tinggi di-downscale dari 1600x719 ke 1080x485 (max 1080px).
# 2026-06-21 23:03:23,860 - INFO - Gambar resolusi tinggi di-downscale dari 1600x903 ke 1080x609 (max 1080px).
# 2026-06-21 23:03:24,115 - INFO - Gambar resolusi tinggi di-downscale dari 1064x1600 ke 718x1080 (max 1080px).
# 2026-06-21 23:03:24,426 - INFO - Gambar resolusi tinggi di-downscale dari 1477x1108 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:24,783 - INFO - Gambar resolusi tinggi di-downscale dari 1599x901 ke 1080x608 (max 1080px).
# 2026-06-21 23:03:24,992 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:25,220 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:25,479 - INFO - Gambar resolusi tinggi di-downscale dari 1440x900 ke 1080x675 (max 1080px).
# 2026-06-21 23:03:25,747 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-21 23:03:26,088 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-21 23:03:26,499 - INFO - Gambar resolusi tinggi di-downscale dari 1365x768 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:26,743 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-06-21 23:03:26,977 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-21 23:03:27,279 - INFO - Gambar resolusi tinggi di-downscale dari 1479x1109 ke 1080x809 (max 1080px).
# 2026-06-21 23:03:27,905 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:28,129 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:28,357 - INFO - Gambar resolusi tinggi di-downscale dari 902x1600 ke 608x1080 (max 1080px).
# 2026-06-21 23:03:28,691 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:29,087 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:29,454 - INFO - Gambar resolusi tinggi di-downscale dari 4000x3000 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:29,752 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:30,034 - INFO - Gambar resolusi tinggi di-downscale dari 1186x1599 ke 801x1080 (max 1080px).
# 2026-06-21 23:03:30,494 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:30,920 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:31,312 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:31,712 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:32,115 - INFO - Gambar resolusi tinggi di-downscale dari 4160x2773 ke 1080x719 (max 1080px).
# 2026-06-21 23:03:32,467 - INFO - Gambar resolusi tinggi di-downscale dari 2773x4160 ke 719x1080 (max 1080px).
# 2026-06-21 23:03:32,830 - INFO - Gambar resolusi tinggi di-downscale dari 2773x4160 ke 719x1080 (max 1080px).
# 2026-06-21 23:03:33,088 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:33,363 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:33,654 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:33,939 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:34,345 - INFO - Gambar resolusi tinggi di-downscale dari 4000x3000 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:34,874 - INFO - Gambar resolusi tinggi di-downscale dari 4000x3000 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:35,385 - INFO - Gambar resolusi tinggi di-downscale dari 4000x3000 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:35,901 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:36,404 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:36,901 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:37,386 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:37,863 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:38,274 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:38,693 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:39,113 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:39,571 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:40,019 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:40,427 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:40,831 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:41,210 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:41,597 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:42,114 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:42,673 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:43,185 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:43,637 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:44,059 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:44,488 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:44,883 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:45,207 - INFO - Gambar resolusi tinggi di-downscale dari 1160x872 ke 1080x811 (max 1080px).
# 2026-06-21 23:03:45,626 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:45,943 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1202 ke 1080x811 (max 1080px).
# 2026-06-21 23:03:46,232 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:46,491 - INFO - Gambar resolusi tinggi di-downscale dari 1477x1108 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:46,752 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:47,023 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:47,277 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:47,556 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:47,869 - INFO - Gambar resolusi tinggi di-downscale dari 872x1160 ke 811x1080 (max 1080px).
# 2026-06-21 23:03:48,230 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:48,614 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:49,067 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:03:49,533 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:03:49,867 - INFO - Gambar resolusi tinggi di-downscale dari 1204x1600 ke 812x1080 (max 1080px).
# 2026-06-21 23:03:50,202 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1204 ke 1080x812 (max 1080px).
# 2026-06-21 23:03:50,684 - INFO - Gambar resolusi tinggi di-downscale dari 2448x3264 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:51,384 - INFO - Gambar resolusi tinggi di-downscale dari 3264x2448 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:51,814 - INFO - Gambar resolusi tinggi di-downscale dari 1440x1080 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:52,091 - INFO - Gambar resolusi tinggi di-downscale dari 963x1280 ke 812x1080 (max 1080px).
# 2026-06-21 23:03:52,368 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:52,624 - INFO - Gambar resolusi tinggi di-downscale dari 853x1280 ke 719x1080 (max 1080px).
# 2026-06-21 23:03:52,894 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:53,269 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1204 ke 1080x812 (max 1080px).
# 2026-06-21 23:03:53,530 - INFO - Gambar resolusi tinggi di-downscale dari 1152x864 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:53,794 - INFO - Gambar resolusi tinggi di-downscale dari 963x1280 ke 812x1080 (max 1080px).
# 2026-06-21 23:03:54,053 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:54,342 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:54,725 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-06-21 23:03:54,992 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:55,236 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:55,444 - INFO - Gambar resolusi tinggi di-downscale dari 1204x1600 ke 812x1080 (max 1080px).
# 2026-06-21 23:03:55,721 - INFO - Gambar resolusi tinggi di-downscale dari 1204x1600 ke 812x1080 (max 1080px).
# 2026-06-21 23:03:56,095 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:56,367 - INFO - Gambar resolusi tinggi di-downscale dari 864x1296 ke 720x1080 (max 1080px).
# 2026-06-21 23:03:56,605 - INFO - Gambar resolusi tinggi di-downscale dari 864x1296 ke 720x1080 (max 1080px).
# 2026-06-21 23:03:56,842 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:57,111 - INFO - Gambar resolusi tinggi di-downscale dari 651x1156 ke 608x1080 (max 1080px).
# 2026-06-21 23:03:57,495 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:58,006 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:03:58,476 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:58,854 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:59,262 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:03:59,657 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:00,140 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:00,630 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:01,136 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:01,620 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:02,126 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:02,604 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:03,111 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:03,594 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:04,062 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:04,517 - INFO - Gambar resolusi tinggi di-downscale dari 4160x2341 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:04,828 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1005 ke 1080x678 (max 1080px).
# 2026-06-21 23:04:05,122 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:05,542 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:05,980 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:06,264 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:06,585 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:06,910 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:07,262 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:07,596 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:07,936 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:08,268 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:11,408 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:11,997 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:12,586 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:13,121 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:13,610 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:14,095 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:14,574 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:15,051 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:15,356 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:15,584 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-21 23:04:15,877 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:16,158 - INFO - Gambar resolusi tinggi di-downscale dari 963x1280 ke 812x1080 (max 1080px).
# 2026-06-21 23:04:16,445 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-21 23:04:16,746 - INFO - Gambar resolusi tinggi di-downscale dari 963x1280 ke 812x1080 (max 1080px).
# 2026-06-21 23:04:17,040 - INFO - Gambar resolusi tinggi di-downscale dari 963x1280 ke 812x1080 (max 1080px).
# 2026-06-21 23:04:17,333 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-21 23:04:17,649 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-06-21 23:04:17,977 - INFO - Gambar resolusi tinggi di-downscale dari 963x1280 ke 812x1080 (max 1080px).
# 2026-06-21 23:04:18,484 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:18,974 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:19,472 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:19,886 - INFO - Gambar resolusi tinggi di-downscale dari 3648x2736 ke 1080x809 (max 1080px).
# 2026-06-21 23:04:20,325 - INFO - Gambar resolusi tinggi di-downscale dari 3648x2736 ke 1080x809 (max 1080px).
# 2026-06-21 23:04:20,848 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-06-21 23:04:21,340 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-06-21 23:04:21,815 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:22,268 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-06-21 23:04:22,719 - INFO - Gambar resolusi tinggi di-downscale dari 4080x3072 ke 1080x813 (max 1080px).
# 2026-06-21 23:04:23,095 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:23,444 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:23,805 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:24,172 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:24,527 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:24,886 - INFO - Gambar resolusi tinggi di-downscale dari 2268x4032 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:25,105 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:25,386 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:25,669 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:25,950 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:26,376 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:26,793 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:27,203 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:27,492 - INFO - Gambar resolusi tinggi di-downscale dari 1600x997 ke 1080x672 (max 1080px).
# 2026-06-21 23:04:27,730 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:27,953 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:28,166 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:28,417 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:04:28,685 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:29,061 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:29,319 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:29,613 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:29,894 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:30,174 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:30,467 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:30,757 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:31,040 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:31,335 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:31,618 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:31,888 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:32,181 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:32,450 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:32,736 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:33,142 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:33,543 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:33,917 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:34,302 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:34,702 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:35,116 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:35,518 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:35,906 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:36,191 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:36,455 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:36,744 - INFO - Gambar resolusi tinggi di-downscale dari 853x1280 ke 719x1080 (max 1080px).
# 2026-06-21 23:04:37,064 - INFO - Gambar resolusi tinggi di-downscale dari 959x1280 ke 809x1080 (max 1080px).
# 2026-06-21 23:04:37,427 - INFO - Gambar resolusi tinggi di-downscale dari 2966x3955 ke 809x1080 (max 1080px).
# 2026-06-21 23:04:37,706 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:37,964 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:38,236 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:38,540 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:38,811 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:39,074 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:39,348 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:39,633 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:39,903 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:40,181 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:40,459 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:40,757 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:41,045 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:41,421 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:41,803 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:42,170 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:42,532 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:42,897 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:43,267 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:43,667 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:44,074 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:44,495 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:44,907 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:45,168 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:45,395 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:45,655 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:45,992 - INFO - Gambar resolusi tinggi di-downscale dari 2296x4080 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:46,360 - INFO - Gambar resolusi tinggi di-downscale dari 4080x2296 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:46,715 - INFO - Gambar resolusi tinggi di-downscale dari 4080x2296 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:46,943 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:47,200 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:47,798 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:48,194 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:48,617 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:48,902 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:49,184 - INFO - Gambar resolusi tinggi di-downscale dari 1600x946 ke 1080x638 (max 1080px).
# 2026-06-21 23:04:49,433 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:49,674 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1074 ke 1080x724 (max 1080px).
# 2026-06-21 23:04:49,955 - INFO - Gambar resolusi tinggi di-downscale dari 1600x879 ke 1080x593 (max 1080px).
# 2026-06-21 23:04:50,199 - INFO - Gambar resolusi tinggi di-downscale dari 864x1152 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:50,518 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1204 ke 1080x812 (max 1080px).
# 2026-06-21 23:04:50,842 - INFO - Gambar resolusi tinggi di-downscale dari 1560x1040 ke 1080x720 (max 1080px).
# 2026-06-21 23:04:51,122 - INFO - Gambar resolusi tinggi di-downscale dari 1280x661 ke 1080x557 (max 1080px).
# 2026-06-21 23:04:51,379 - INFO - Gambar resolusi tinggi di-downscale dari 2928x1512 ke 1080x557 (max 1080px).
# 2026-06-21 23:04:51,578 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:51,853 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:52,087 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:04:52,510 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:52,930 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:53,436 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:53,825 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:54,212 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:54,585 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:54,956 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:55,340 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:55,933 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:56,362 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:56,683 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:57,004 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-06-21 23:04:58,226 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:58,513 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:04:58,996 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:59,203 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:59,566 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:04:59,884 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:00,213 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:00,626 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:00,920 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:01,409 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:02,009 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:02,290 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:02,528 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:02,853 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:03,196 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:03,469 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:03,737 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:04,010 - INFO - Gambar resolusi tinggi di-downscale dari 540x1170 ke 498x1080 (max 1080px).
# 2026-06-21 23:05:04,871 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:05,311 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:05,614 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:07,717 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:05:08,062 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:09,759 - INFO - Gambar resolusi tinggi di-downscale dari 708x1280 ke 597x1080 (max 1080px).
# 2026-06-21 23:05:10,651 - INFO - Gambar resolusi tinggi di-downscale dari 1156x521 ke 1080x486 (max 1080px).
# 2026-06-21 23:05:11,582 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:11,964 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:13,084 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:15,878 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:16,230 - INFO - Gambar resolusi tinggi di-downscale dari 1125x1150 ke 1056x1080 (max 1080px).
# 2026-06-21 23:05:16,827 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:19,216 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:19,467 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-06-21 23:05:20,258 - INFO - Gambar resolusi tinggi di-downscale dari 1125x385 ke 1080x369 (max 1080px).
# 2026-06-21 23:05:20,552 - INFO - Gambar resolusi tinggi di-downscale dari 1138x1600 ke 768x1080 (max 1080px).
# 2026-06-21 23:05:20,849 - INFO - Gambar resolusi tinggi di-downscale dari 1180x1377 ke 925x1080 (max 1080px).
# 2026-06-21 23:05:21,226 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:21,516 - INFO - Gambar resolusi tinggi di-downscale dari 719x1280 ke 606x1080 (max 1080px).
# 2026-06-21 23:05:21,742 - INFO - Gambar resolusi tinggi di-downscale dari 1202x1600 ke 811x1080 (max 1080px).
# 2026-06-21 23:05:22,393 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:22,727 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:23,023 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:23,715 - INFO - Gambar resolusi tinggi di-downscale dari 996x1280 ke 840x1080 (max 1080px).
# 2026-06-21 23:05:24,010 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:24,206 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-21 23:05:24,756 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:25,085 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:25,420 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-21 23:05:25,656 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-06-21 23:05:25,976 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-06-21 23:05:26,304 - INFO - Gambar resolusi tinggi di-downscale dari 1280x961 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:26,669 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:27,011 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:27,697 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-06-21 23:05:27,951 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-06-21 23:05:28,191 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-06-21 23:05:28,607 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:05:28,827 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:29,098 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:29,390 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:29,743 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:05:30,315 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1111 ke 1049x1080 (max 1080px).
# 2026-06-21 23:05:30,740 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:05:30,992 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:05:31,186 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:05:31,350 - INFO - Gambar resolusi tinggi di-downscale dari 576x1280 ke 486x1080 (max 1080px).
# 2026-06-21 23:05:31,558 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# ...
# 2026-06-21 23:07:22,250 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:22,640 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:22,909 - INFO - Gambar resolusi tinggi di-downscale dari 1389x534 ke 1080x415 (max 1080px).
# 2026-06-21 23:07:23,120 - INFO - Gambar resolusi tinggi di-downscale dari 1600x521 ke 1080x351 (max 1080px).
# 2026-06-21 23:07:23,289 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:23,530 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-06-21 23:07:24,033 - INFO - Gambar resolusi tinggi di-downscale dari 3936x2624 ke 1080x720 (max 1080px).
# 2026-06-21 23:07:24,401 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:24,632 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:25,015 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:25,404 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:25,825 - INFO - Gambar resolusi tinggi di-downscale dari 3127x4160 ke 811x1080 (max 1080px).
# 2026-06-21 23:07:26,108 - INFO - Gambar resolusi tinggi di-downscale dari 1204x1600 ke 812x1080 (max 1080px).
# 2026-06-21 23:07:26,401 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:26,682 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:26,972 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:27,381 - INFO - Gambar resolusi tinggi di-downscale dari 4000x3000 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:27,648 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:29,605 - INFO - Gambar resolusi tinggi di-downscale dari 4032x2268 ke 1080x607 (max 1080px).
# 2026-06-21 23:07:29,925 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-21 23:07:30,123 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-06-21 23:07:30,334 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:30,643 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:31,029 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:31,326 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:31,595 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1207 ke 1046x1080 (max 1080px).
# 2026-06-21 23:07:32,110 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:32,449 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-06-21 23:07:32,737 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:32,967 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:33,250 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-06-21 23:07:33,563 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-06-21 23:07:33,924 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:34,272 - INFO - Gambar resolusi tinggi di-downscale dari 1536x2730 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:34,539 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:34,769 - INFO - Gambar resolusi tinggi di-downscale dari 1600x930 ke 1080x627 (max 1080px).
# 2026-06-21 23:07:35,064 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-06-21 23:07:35,306 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:35,526 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:35,833 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:36,347 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:36,654 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-06-21 23:07:36,914 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:37,274 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:37,629 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:37,980 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:38,344 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:38,691 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:39,034 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:39,315 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:39,622 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-06-21 23:07:39,861 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-06-21 23:07:40,205 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:40,739 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:40,984 - INFO - Gambar resolusi tinggi di-downscale dari 1024x1536 ke 720x1080 (max 1080px).
# 2026-06-21 23:07:41,269 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:41,492 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1065 ke 1080x718 (max 1080px).
# 2026-06-21 23:07:41,758 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:42,031 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:42,307 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:42,590 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:42,862 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:43,085 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:43,349 - INFO - Gambar resolusi tinggi di-downscale dari 1280x854 ke 1080x720 (max 1080px).
# 2026-06-21 23:07:43,625 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:43,981 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:44,316 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:44,597 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:44,830 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:45,259 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:45,682 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:45,976 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:46,258 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:46,527 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:46,934 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:47,335 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:47,721 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:48,051 - INFO - Gambar resolusi tinggi di-downscale dari 591x1280 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:48,406 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:48,677 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:48,965 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-06-21 23:07:49,163 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:49,367 - INFO - Gambar resolusi tinggi di-downscale dari 1280x724 ke 1080x610 (max 1080px).
# 2026-06-21 23:07:49,704 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:50,003 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:50,297 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:50,599 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:50,903 - INFO - Gambar resolusi tinggi di-downscale dari 610x1356 ke 485x1080 (max 1080px).
# 2026-06-21 23:07:51,173 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1762 ke 1080x647 (max 1080px).
# 2026-06-21 23:07:51,430 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-06-21 23:07:51,700 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-06-21 23:07:52,012 - INFO - Gambar resolusi tinggi di-downscale dari 3840x2160 ke 1080x607 (max 1080px).
# 2026-06-21 23:07:52,258 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:52,519 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:52,848 - INFO - Gambar resolusi tinggi di-downscale dari 1600x853 ke 1080x575 (max 1080px).
# 2026-06-21 23:07:53,434 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:53,847 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:54,151 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:54,460 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:54,721 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1002 ke 1080x924 (max 1080px).
# 2026-06-21 23:07:55,031 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-06-21 23:07:55,277 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:55,638 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:55,939 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:07:56,146 - INFO - Gambar resolusi tinggi di-downscale dari 815x1180 ke 745x1080 (max 1080px).
# 2026-06-21 23:07:56,572 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:56,967 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:57,258 - INFO - Gambar resolusi tinggi di-downscale dari 1280x996 ke 1080x840 (max 1080px).
# 2026-06-21 23:07:57,585 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:07:58,051 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:58,352 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1272 ke 1080x1073 (max 1080px).
# 2026-06-21 23:07:58,983 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:07:59,325 - INFO - Gambar resolusi tinggi di-downscale dari 1600x894 ke 1080x603 (max 1080px).
# 2026-06-21 23:07:59,580 - INFO - Gambar resolusi tinggi di-downscale dari 871x1600 ke 587x1080 (max 1080px).
# 2026-06-21 23:08:00,060 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:00,359 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:00,828 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-06-21 23:08:01,130 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-06-21 23:08:01,384 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:08:01,803 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-06-21 23:08:02,214 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-06-21 23:08:02,651 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-06-21 23:08:02,987 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:03,502 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-06-21 23:08:03,801 - INFO - Gambar resolusi tinggi di-downscale dari 1280x782 ke 1080x659 (max 1080px).
# 2026-06-21 23:08:04,081 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:04,378 - INFO - Gambar resolusi tinggi di-downscale dari 3027x1638 ke 1080x584 (max 1080px).
# 2026-06-21 23:08:04,646 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:08:04,977 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-06-21 23:08:05,305 - INFO - Gambar resolusi tinggi di-downscale dari 583x1600 ke 393x1080 (max 1080px).
# 2026-06-21 23:08:05,473 - INFO - Gambar resolusi tinggi di-downscale dari 1296x892 ke 1080x743 (max 1080px).
# 2026-06-21 23:08:05,738 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:06,035 - INFO - Gambar resolusi tinggi di-downscale dari 2595x1638 ke 1080x681 (max 1080px).
# 2026-06-21 23:08:06,346 - INFO - Gambar resolusi tinggi di-downscale dari 2932x1760 ke 1080x648 (max 1080px).
# 2026-06-21 23:08:06,607 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:07,123 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:07,476 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:07,831 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:08,180 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:08,530 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:08,876 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:09,455 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:09,893 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:10,264 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-06-21 23:08:10,633 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# Berhasil mengumpulkan 6020 wajah dari 1000 gambar uji dalam 322.40 detik (deteksi+alignment).

# %% [markdown]
# ## 2. Metode Berbasis Geometri: Geometry-Based Landmarks
# Metode berbasis geometri mengidentifikasi wajah dengan mengukur jarak relatif antar landmark wajah utama seperti mata, hidung, dan mulut secara scale-invariant pada 6 jarak Euclidean berpasangan.

# %%
def extract_geometry_features(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    h_idx, w_idx = gray.shape
    
    def get_landmark_centroid(y_start, y_end, x_start, x_end):
        ys, ye = int(y_start * h_idx), int(y_end * h_idx)
        xs, xe = int(x_start * w_idx), int(x_end * w_idx)
        sub_img = gray[ys:ye, xs:xe]
        
        threshold = np.percentile(sub_img, 10)
        dark_pixels = np.argwhere(sub_img <= threshold)
        if len(dark_pixels) == 0:
            cy, cx = (ys + ye) / 2, (xs + xe) / 2
        else:
            cy = ys + np.mean(dark_pixels[:, 0])
            cx = xs + np.mean(dark_pixels[:, 1])
        return np.array([cx, cy])
        
    left_eye = get_landmark_centroid(0.2, 0.4, 0.2, 0.45)
    right_eye = get_landmark_centroid(0.2, 0.4, 0.55, 0.8)
    nose = get_landmark_centroid(0.45, 0.7, 0.4, 0.6)
    mouth = get_landmark_centroid(0.7, 0.95, 0.3, 0.7)
    
    dists = [
        np.linalg.norm(left_eye - right_eye),
        np.linalg.norm(left_eye - nose),
        np.linalg.norm(right_eye - nose),
        np.linalg.norm(left_eye - mouth),
        np.linalg.norm(right_eye - mouth),
        np.linalg.norm(nose - mouth)
    ]
    
    eye_dist = dists[0] if dists[0] > 0 else 1.0
    normalized_dists = [d / eye_dist for d in dists]
    return np.array(normalized_dists, dtype=np.float32)

print("Evaluasi Geometry-Based...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_geometry_features(face) for p, face in query_faces.items()}
dataset_feats = np.array([extract_geometry_features(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('Geometry-Based', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi Geometry-Based...
# --- Geometry-Based Evaluated ---
# Best Threshold: 0.05
# Accuracy      : 0.3450
# F1-Score      : 0.4087

# %% [markdown]
# ## 3. Metode Holistik: PCA (Eigenfaces)
# Principal Component Analysis (PCA) mereduksi dimensi gambar dari wajah ter-resize dengan memproyeksikannya ke eigenfaces berdimensi 150.

# %%
print("Evaluasi PCA (Eigenfaces)... ")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Flatten wajah ke grayscale
def flatten_gray_face(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    return gray.flatten().astype(np.float32) / 255.0

query_flat = np.array([flatten_gray_face(query_faces[p]) for p in ["A", "B", "C"]])
dataset_flat = np.array([flatten_gray_face(f["cropped_face"]) for f in dataset_faces])

# 2. Fit PCA pada kumpulan wajah dataset
n_components = min(150, len(dataset_faces))
pca = PCA(n_components=n_components, svd_solver='randomized', whiten=True)
pca.fit(dataset_flat)

# 3. Proyeksi
query_projected = pca.transform(query_flat)
dataset_projected = pca.transform(dataset_flat)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('PCA (Holistik)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi PCA (Eigenfaces)...
# --- PCA (Holistik) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.5477
# F1-Score      : 0.4508

# %% [markdown]
# ## 4. Metode Berbasis Fitur: LBP & HOG
# Mengekstrak fitur lokal menggunakan **Local Binary Pattern (LBP)** dan **Histogram of Oriented Gradients (HOG)**.

# %%
def extract_lbp_hist(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    n_bins = n_points + 2
    hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=(0, n_bins), density=True)
    return hist.astype(np.float32)

print("Evaluasi LBP...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_lbp_hist(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_lbp_hist(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

def extract_hog_vector(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    feat = hog(gray, orientations=8, pixels_per_cell=(8, 8),
               cells_per_block=(2, 2), visualize=False)
    return feat.astype(np.float32)

print("\nEvaluasi HOG...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_hog_vector(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_hog_vector(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('HOG (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP...
# --- LBP (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.25
# Accuracy      : 0.4413
# F1-Score      : 0.4256
#
# Evaluasi HOG...
# --- HOG (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.30
# Accuracy      : 0.5740
# F1-Score      : 0.4706

# %% [markdown]
# ## 5. Metode Hibrida: LBP + PCA
# Menggabungkan tekstur lokal dari LBP mentah dengan reduksi dimensi PCA (50 komponen).

# %%
def extract_raw_lbp(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    return lbp.ravel().astype(np.float32)

print("Evaluasi LBP + PCA (Hibrida)...")
mem_before = get_memory_usage()
t0 = time.time()

query_raw_lbp = np.array([extract_raw_lbp(query_faces[p]) for p in ["A", "B", "C"]])
dataset_raw_lbp = np.array([extract_raw_lbp(f["cropped_face"]) for f in dataset_faces])

n_components_hyb = min(50, len(dataset_faces))
pca_lbp = PCA(n_components=n_components_hyb, svd_solver='randomized', whiten=True)
pca_lbp.fit(dataset_raw_lbp)

query_projected = pca_lbp.transform(query_raw_lbp)
dataset_projected = pca_lbp.transform(dataset_raw_lbp)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP + PCA (Hibrida)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP + PCA (Hibrida)...
# --- LBP + PCA (Hibrida) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.4593
# F1-Score      : 0.4106

# %% [markdown]
# ## 6. Metode Deep Learning: Facenet (DeepFace)
# Mengekstrak embedding berdimensi 128 dari model Deep Learning Facenet (diload dari cache jika tersedia).

# %%
print("Evaluasi Facenet...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="Facenet", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    # Cek cache Facenet
    cached_found = False
    if img_name in preloaded_caches["Facenet"]:
        for cached_entry in preloaded_caches["Facenet"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        # Ekstraksi Baru dan simpan cache
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "Facenet")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["Facenet"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 100 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (Facenet)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi Facenet...
# --- DeepFace (Facenet) Evaluated ---
# Best Threshold: 0.40
# Accuracy      : 0.8743
# F1-Score      : 0.7351
# 198

# %% [markdown]
# ## 7. Metode Deep Learning: VGG-Face (DeepFace)
# Mengekstrak embedding berdimensi 2622 dari model Deep Learning VGG-Face (diload dari cache jika tersedia).

# %%
print("Evaluasi VGG-Face...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="VGG-Face", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["VGG-Face"]:
        for cached_entry in preloaded_caches["VGG-Face"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "VGG-Face")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["VGG-Face"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (VGG-Face)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi VGG-Face...
# --- DeepFace (VGG-Face) Evaluated ---
# Best Threshold: 0.60
# Accuracy      : 0.8943
# F1-Score      : 0.7466
# 305

# %% [markdown]
# ## 8. Metode Deep Learning: ArcFace (DeepFace)
# Mengekstrak embedding berdimensi 512 dari model Deep Learning ArcFace (diload dari cache jika tersedia). Ini adalah model yang digunakan oleh sistem utama GUI.

# %%
print("Evaluasi ArcFace...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="ArcFace", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["ArcFace"]:
        for cached_entry in preloaded_caches["ArcFace"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "ArcFace")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["ArcFace"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (ArcFace)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras setelah selesai pengujian
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi ArcFace...
# --- DeepFace (ArcFace) Evaluated ---
# Best Threshold: 0.65
# Accuracy      : 0.8610
# F1-Score      : 0.7114
# 404

# %% [markdown]
# ## 9. Visualisasi dan Perbandingan Kinerja
# Menampilkan tabel perbandingan DataFrame lengkap untuk kedelapan model, dan memvisualisasikan F1-Score, waktu eksekusi total (ekstraksi + pencocokan), serta tambahan penggunaan RAM.

# %%
df_results = pd.DataFrame(results)
print("\n--- Hasil Perbandingan Lengkap (8 Model) ---")
print(df_results.to_string(index=False))

# Tableau 10 color palette untuk visualisasi premium
colors = ['#4E79A7', '#F28E2B', '#E15759', '#76B7B2', '#59A14F', '#EDC948', '#B07AA1', '#FF9DA7']

plt.figure(figsize=(18, 6))

# 1. Plot F1-Score
plt.subplot(1, 3, 1)
bars1 = plt.bar(df_results['Model'], df_results['F1-Score'], color=colors[:len(df_results)])
plt.title('F1-Score Model (Tertinggi Terbaik)', fontsize=12, fontweight='bold')
plt.ylim(0, 1.15)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('F1-Score')
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.02, f"{yval:.2f}", ha='center', va='bottom', fontsize=9)

# 2. Plot Stacked Waktu Komputasi per Tahap (Deteksi + Ekstraksi + Inferensi)
plt.subplot(1, 3, 2)
det_times = df_results['Detection Time (s)']
feat_times = df_results['Feature Extraction Time (s)']
infer_times = df_results['Inference Time (s)']
plt.bar(df_results['Model'], det_times, color='#B07AA1', label='Deteksi & Alignment')
plt.bar(df_results['Model'], feat_times, bottom=det_times, color='#4E79A7', label='Ekstraksi Fitur')
plt.bar(df_results['Model'], infer_times, bottom=det_times + feat_times, color='#F28E2B', label='Inferensi/Matching')
total_time = det_times + feat_times + infer_times
plt.title('Waktu Komputasi per Tahap (detik)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Waktu (detik)')
plt.legend(fontsize=7, loc='upper left')
for i, total in enumerate(total_time):
    plt.text(i, total + (total * 0.02) + 0.05, f"{total:.2f}s", ha='center', va='bottom', fontsize=9)

# 3. Plot Memory Usage
plt.subplot(1, 3, 3)
bars3 = plt.bar(df_results['Model'], df_results['Memory Usage (MB)'], color=colors[:len(df_results)])
plt.title('Penggunaan Memori Tambahan (MB)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Memori (MB)')
for bar in bars3:
    yval = bar.get_height()
    # Jaga formatting
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.1, f"{yval:.1f} MB", ha='center', va='bottom', fontsize=9)

plt.tight_layout()
assets_dir = os.path.join(project_root, "assets")
os.makedirs(assets_dir, exist_ok=True)
plt.savefig(os.path.join(assets_dir, "perbandingan_kinerja_mtcnn.png"), dpi=300, bbox_inches="tight")
plt.show()
# Out:
# --- Hasil Perbandingan Lengkap (8 Model) ---
#                Model  Accuracy  Precision   Recall  F1-Score  Best Threshold  Feature Extraction Time (s)  Inference Time (s)  Memory Usage (MB)  Detection Time (s)
#       Geometry-Based  0.345000   0.259557 0.960396  0.408667            0.05                     1.794549            6.875577           0.796875          322.398885
#       PCA (Holistik)  0.547667   0.315760 0.787836  0.450830            0.95                     3.439454            7.505657         284.753906          322.398885
# LBP (Berbasis Fitur)  0.441333   0.280868 0.878359  0.425634            0.25                    11.494441            7.472873           0.781250          322.398885
# HOG (Berbasis Fitur)  0.574000   0.332748 0.803395  0.470588            0.30                    18.239864            8.448654         132.109375          322.398885
#  LBP + PCA (Hibrida)  0.459333   0.276284 0.799151  0.410610            0.95                    11.062305            7.749343         412.812500          322.398885
#   DeepFace (Facenet)  0.874333   0.730447 0.739745  0.735067            0.40                  1607.450316            8.306349           0.000000          322.398885
#  DeepFace (VGG-Face)  0.894333   0.858456 0.660537  0.746603            0.60                  1743.119371            9.228585         534.734375          322.398885
#   DeepFace (ArcFace)  0.861000   0.696477 0.727016  0.711419            0.65                  1243.435217           11.005755           0.000000          322.398885
