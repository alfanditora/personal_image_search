# %% [markdown]
# # Eksplorasi Algoritma Face Recognition (SCRFD Detector) + Uji Skalabilitas
#
# Notebook ini bertujuan untuk membandingkan delapan metode pengenalan wajah sesuai dengan uji yang dilakukan di sistem GUI:
# 1. **Geometry-Based (Geometric Landmarks)**
# 2. **PCA (Holistik)**
# 3. **LBP (Berbasis Fitur)**
# 4. **HOG (Berbasis Fitur)**
# 5. **LBP + PCA (Hibrida)**
# 6. **DeepFace - Facenet (Deep Learning)**
# 7. **DeepFace - VGG-Face (Deep Learning)**
# 8. **DeepFace - ArcFace (Deep Learning)**
#
# Pengujian dilakukan dengan mencocokkan foto selfie kueri (Person A, B, C) dengan seluruh 1000 gambar uji di dataset, menggunakan metode pencocokan jarak Cosine langsung (tanpa SVM) seperti pada sistem GUI. Evaluasi akan mencari threshold optimal untuk masing-masing model untuk perbandingan yang adil.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import time
import os
import psutil
import sys
import json
import hashlib
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from skimage.feature import local_binary_pattern, hog
from deepface import DeepFace
import pandas as pd

# Fungsi untuk mendapatkan penggunaan memori saat ini dalam MB
def get_memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)

# Menemukan project root
possible_roots = [
    os.path.abspath("."),
    os.path.abspath(".."),
    os.path.abspath("../..")
]
project_root = None
for root in possible_roots:
    if os.path.exists(os.path.join(root, "core")) and os.path.exists(os.path.join(root, "cache_io")):
        project_root = root
        break
if project_root is None:
    project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(f"Project root diatur ke: {project_root}")

from src.core.detector import FaceDetector
from src.cache_io.cache_handler import CacheHandler
# Out:
# Project root diatur ke: c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search

# %% [markdown]
# ## 1. Persiapan Dataset & Integrasi Cache
# Memuat dataset pengujian dari `D:\dataset\testset`, foto kueri dari `queries/`, ground truth dari `ground_truth.json`, dan inisialisasi model cache terpisah untuk masing-masing model Deep Learning menggunakan `CacheHandler` dari `cache_io`.

# %%
TESTSET_DIR = "D:/dataset/testset"
TEST_IMAGES_DIR = os.path.join(TESTSET_DIR, "test_case")
QUERIES_DIR = os.path.join(TESTSET_DIR, "queries")
GROUND_TRUTH_PATH = os.path.join(TESTSET_DIR, "ground_truth.json")

# 1. Load Ground Truth
with open(GROUND_TRUTH_PATH, "r", encoding="utf-8") as f:
    ground_truth = json.load(f)

test_images = [f for f in os.listdir(TEST_IMAGES_DIR) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
LIMIT_IMAGES = None  # Ganti dengan angka (misal 100) untuk pengujian cepat, atau None untuk seluruh gambar
if LIMIT_IMAGES is not None:
    test_images = test_images[:LIMIT_IMAGES]
print(f"Total Gambar Uji: {len(test_images)}")
print(f"Total Gambar di Ground Truth: {len(ground_truth)}")

# 2. Inisialisasi Face Detector
detector = FaceDetector("scrfd")

# 3. Subclass CacheHandler untuk menentukan direktori cache secara dinamis per model
class ModelCacheHandler(CacheHandler):
    def __init__(self, folder_input_path: str, model_name: str):
        super().__init__(folder_input_path)
        self.model_name = model_name.lower()
        self.cache_dir = os.path.join(self.folder_input_path, f".face_cache_scrfd_{self.model_name}")
        os.makedirs(self.cache_dir, exist_ok=True)

    def cache_exists(self, file_name: str, bbox: tuple) -> bool:
        bbox_str = f"_{bbox[0]}_{bbox[1]}_{bbox[2]}_{bbox[3]}"
        unique_id = hashlib.md5((file_name + bbox_str).encode('utf-8')).hexdigest()
        cache_file_path = os.path.join(self.cache_dir, f"{unique_id}.json")
        return os.path.exists(cache_file_path)

# 4. Load Preloaded Cache untuk efisiensi eksekusi notebook
models_dl = ["ArcFace", "Facenet", "VGG-Face"]
handlers = {model: ModelCacheHandler(TEST_IMAGES_DIR, model) for model in models_dl}
preloaded_caches = {}

for model in models_dl:
    print(f"Memuat cache untuk model {model}...")
    cache_list = handlers[model].muat_seluruh_cache()
    model_cache = {}
    for entry in cache_list:
        img_name = entry["file_name"]
        if img_name not in model_cache:
            model_cache[img_name] = []
        model_cache[img_name].append(entry)
    preloaded_caches[model] = model_cache

# 5. Helper untuk memuat wajah (face ROIs) — selalu menggunakan detector untuk alignment konsisten
def get_face_rois(img_path, detector):
    # Selalu jalankan detector.detect_and_crop agar affine alignment 5-titik diterapkan
    # secara konsisten di setiap run, tanpa bergantung pada cache bbox yang mungkin
    # dihasilkan oleh detector berbeda atau tanpa alignment.
    return detector.detect_and_crop(img_path)

def extract_deepface_embedding(face_img, model_name):
    if len(face_img.shape) == 2:
        face_img = cv2.cvtColor(face_img, cv2.COLOR_GRAY2BGR)
    elif face_img.shape[2] == 4:
        face_img = face_img[:, :, :3]
    # Downscale check for safe preprocessing
    h_f, w_f = face_img.shape[:2]
    if max(h_f, w_f) > 1080:
        scale_f = 1080.0 / max(h_f, w_f)
        face_img = cv2.resize(face_img, (int(w_f * scale_f), int(h_f * scale_f)), interpolation=cv2.INTER_AREA)
    objs = DeepFace.represent(
        img_path=face_img,
        model_name=model_name,
        enforce_detection=False,
        detector_backend="skip"
    )
    return np.array(objs[0]['embedding'], dtype=np.float32)

# 6. Ekstraksi Wajah untuk Kueri
queries = {
    "A": os.path.join(QUERIES_DIR, "selfie_A.jpeg"),
    "B": os.path.join(QUERIES_DIR, "selfie_B.jpg"),
    "C": os.path.join(QUERIES_DIR, "selfie_C.jpg")
}
query_faces = {}
for person, path in queries.items():
    faces = detector.detect_and_crop(path)
    if faces:
        query_faces[person] = faces[0]["cropped_face"]
        print(f"Wajah kueri Person {person} berhasil dideteksi.")
    else:
        raise RuntimeError(f"Gagal mendeteksi wajah pada kueri: {path}")

# 7. Kumpulkan semua wajah terdeteksi dari dataset gambar uji (Face Cropping tunggal untuk keadilan evaluasi)
print("Mengumpulkan wajah dari dataset gambar uji...")
t0 = time.time()
dataset_faces = [] # list of dict: {"img_name": str, "cropped_face": np.ndarray, "bbox": tuple}
for img_name in test_images:
    img_path = os.path.join(TEST_IMAGES_DIR, img_name)
    rois = get_face_rois(img_path, detector)
    for roi in rois:
        dataset_faces.append({
            "img_name": img_name,
            "cropped_face": roi["cropped_face"],
            "bbox": roi["bbox"]
        })
detection_time = time.time() - t0
print(f"Berhasil mengumpulkan {len(dataset_faces)} wajah dari {len(test_images)} gambar uji dalam {detection_time:.2f} detik (deteksi+alignment).")

# Penampung hasil komparasi
results = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-Score': [],
    'Best Threshold': [],
    'Feature Extraction Time (s)': [],
    'Inference Time (s)': [],
    'Memory Usage (MB)': [],
    'Detection Time (s)': []
}

# Fungsi pembantu evaluasi umum
def evaluate_matching_model(model_name, query_feats, dataset_feats, dataset_face_metadata, feat_extract_time, mem_used):
    t0 = time.time()
    # Evaluasi jarak Cosine secara matriks/ter-vektorisasi
    # query_feats: dict of {person: vector}
    # dataset_feats: array of shape (N_faces, dim)
    
    persons = ["A", "B", "C"]
    # Hitung semua jarak Cosine antara kueri dan wajah di dataset
    # Jarak Cosine = 1.0 - Cosine Similarity
    distances = {}
    for p in persons:
        q_feat = query_feats[p]
        q_norm = q_feat / (np.linalg.norm(q_feat) + 1e-10)
        
        # dataset_feats shape (N, dim)
        ds_norms = np.linalg.norm(dataset_feats, axis=1, keepdims=True) + 1e-10
        ds_normed = dataset_feats / ds_norms
        
        sims = np.dot(ds_normed, q_norm)
        sims = np.clip(sims, -1.0, 1.0)
        distances[p] = 1.0 - sims
        
    # Mencari threshold optimal dari 0.05 ke 0.95 dengan step 0.05
    thresholds = np.arange(0.05, 1.0, 0.05)
    best_f1 = -1
    best_thresh = 0.4
    best_metrics = {}
    
    # Struktur data target (ground truth)
    # Bentuk ground truth flat (1000 gambar * 3 orang = 3000 pasang)
    y_true = []
    for img_name in test_images:
        gt_img = ground_truth.get(img_name, {"contains_person_A": False, "contains_person_B": False, "contains_person_C": False})
        y_true.append(gt_img.get("contains_person_A", False))
        y_true.append(gt_img.get("contains_person_B", False))
        y_true.append(gt_img.get("contains_person_C", False))
    y_true = np.array(y_true, dtype=bool)
    
    # Lakukan grid search threshold
    for thresh in thresholds:
        # Lakukan prediksi untuk setiap gambar uji
        y_pred = []
        for img_name in test_images:
            # Cari indeks wajah-wajah yang terdeteksi di gambar ini
            indices = [i for i, meta in enumerate(dataset_face_metadata) if meta["img_name"] == img_name]
            
            for p in persons:
                if not indices:
                    # Tidak ada wajah terdeteksi
                    y_pred.append(False)
                else:
                    # Ambil jarak terkecil (wajah paling mirip) untuk kueri person p
                    min_dist = np.min(distances[p][indices])
                    y_pred.append(min_dist <= thresh)
                    
        y_pred = np.array(y_pred, dtype=bool)
        f1 = f1_score(y_true, y_pred, zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_thresh = thresh
            best_metrics = {
                'Accuracy': accuracy_score(y_true, y_pred),
                'Precision': precision_score(y_true, y_pred, zero_division=0),
                'Recall': recall_score(y_true, y_pred, zero_division=0),
                'F1-Score': f1
            }
            
    infer_time = time.time() - t0
    
    # Catat ke tabel komparasi
    results['Model'].append(model_name)
    results['Accuracy'].append(best_metrics['Accuracy'])
    results['Precision'].append(best_metrics['Precision'])
    results['Recall'].append(best_metrics['Recall'])
    results['F1-Score'].append(best_metrics['F1-Score'])
    results['Best Threshold'].append(best_thresh)
    results['Feature Extraction Time (s)'].append(feat_extract_time)
    results['Inference Time (s)'].append(infer_time)
    results['Memory Usage (MB)'].append(mem_used)
    results['Detection Time (s)'].append(detection_time)
    
    print(f"--- {model_name} Evaluated ---")
    print(f"Best Threshold: {best_thresh:.2f}")
    print(f"Accuracy      : {best_metrics['Accuracy']:.4f}")
    print(f"F1-Score      : {best_metrics['F1-Score']:.4f}")
# Out:
# 2026-07-02 02:38:30,234 - INFO - Menginisialisasi detektor wajah SCRFD...
# Total Gambar Uji: 1000
# Total Gambar di Ground Truth: 1000
# 2026-07-02 02:38:30,664 - INFO - Detektor wajah SCRFD berhasil diinisialisasi dari c:\Users\vivobook\OneDrive\Documents\TA\personal_image_search
ke 810x1080 (max 1080px).
# 2026-07-02 02:39:24,590 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1204 ke 1080x812 (max 1080px).
# 2026-07-02 02:39:24,673 - INFO - Gambar resolusi tinggi di-downscale dari 1560x1040 ke 1080x720 (max 1080px).
# 2026-07-02 02:39:24,734 - INFO - Gambar resolusi tinggi di-downscale dari 1280x661 ke 1080x557 (max 1080px).
# 2026-07-02 02:39:24,835 - INFO - Gambar resolusi tinggi di-downscale dari 2928x1512 ke 1080x557 (max 1080px).
# 2026-07-02 02:39:24,897 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:24,967 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:25,031 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:25,191 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:25,360 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:25,551 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:25,738 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:25,919 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:26,087 - INFO - Gambar resolusi tinggi di-downscale dari 4096x3072 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:26,245 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:26,430 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:26,615 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:26,799 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:26,883 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:26,949 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:27,155 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:27,216 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:27,321 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,380 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,438 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,495 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,550 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,603 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,657 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,714 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,769 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,825 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,884 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,938 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:27,995 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:28,059 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:28,122 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:28,179 - INFO - Gambar resolusi tinggi di-downscale dari 540x1170 ke 498x1080 (max 1080px).
# 2026-07-02 02:39:28,359 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:28,427 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:28,492 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:28,905 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:39:28,979 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:29,248 - INFO - Gambar resolusi tinggi di-downscale dari 708x1280 ke 597x1080 (max 1080px).
# 2026-07-02 02:39:29,391 - INFO - Gambar resolusi tinggi di-downscale dari 1156x521 ke 1080x486 (max 1080px).
# 2026-07-02 02:39:29,535 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:29,592 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:29,741 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:30,154 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:30,239 - INFO - Gambar resolusi tinggi di-downscale dari 1125x1150 ke 1056x1080 (max 1080px).
# 2026-07-02 02:39:30,339 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:30,741 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:30,813 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-07-02 02:39:30,946 - INFO - Gambar resolusi tinggi di-downscale dari 1125x385 ke 1080x369 (max 1080px).
# 2026-07-02 02:39:31,025 - INFO - Gambar resolusi tinggi di-downscale dari 1138x1600 ke 768x1080 (max 1080px).
# 2026-07-02 02:39:31,123 - INFO - Gambar resolusi tinggi di-downscale dari 1180x1377 ke 925x1080 (max 1080px).
# 2026-07-02 02:39:31,267 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:31,382 - INFO - Gambar resolusi tinggi di-downscale dari 719x1280 ke 606x1080 (max 1080px).
# 2026-07-02 02:39:31,512 - INFO - Gambar resolusi tinggi di-downscale dari 1202x1600 ke 811x1080 (max 1080px).
# 2026-07-02 02:39:31,717 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:31,840 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:31,948 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:32,143 - INFO - Gambar resolusi tinggi di-downscale dari 996x1280 ke 840x1080 (max 1080px).
# 2026-07-02 02:39:32,243 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:32,337 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-02 02:39:32,541 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:32,637 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:32,747 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-02 02:39:32,842 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-07-02 02:39:32,988 - INFO - Gambar resolusi tinggi di-downscale dari 1280x958 ke 1080x808 (max 1080px).
# 2026-07-02 02:39:33,096 - INFO - Gambar resolusi tinggi di-downscale dari 1280x961 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:33,217 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:33,385 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:33,634 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-07-02 02:39:33,716 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-07-02 02:39:33,797 - INFO - Gambar resolusi tinggi di-downscale dari 1600x800 ke 1080x540 (max 1080px).
# 2026-07-02 02:39:33,945 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:39:34,037 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:34,132 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:34,228 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:34,349 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:34,511 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1111 ke 1049x1080 (max 1080px).
# 2026-07-02 02:39:34,608 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:39:34,679 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-02 02:39:34,758 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-02 02:39:34,837 - INFO - Gambar resolusi tinggi di-downscale dari 576x1280 ke 486x1080 (max 1080px).
# 2026-07-02 02:39:34,961 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:35,115 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:35,253 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:35,420 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:35,614 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:39:36,030 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-02 02:39:36,133 - INFO - Gambar resolusi tinggi di-downscale dari 1080x1520 ke 767x1080 (max 1080px).
# 2026-07-02 02:39:36,232 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# ...
# 2026-07-02 02:40:23,056 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:23,261 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:23,321 - INFO - Gambar resolusi tinggi di-downscale dari 1389x534 ke 1080x415 (max 1080px).
# 2026-07-02 02:40:23,382 - INFO - Gambar resolusi tinggi di-downscale dari 1600x521 ke 1080x351 (max 1080px).
# 2026-07-02 02:40:23,447 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:23,517 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-07-02 02:40:23,758 - INFO - Gambar resolusi tinggi di-downscale dari 3936x2624 ke 1080x720 (max 1080px).
# 2026-07-02 02:40:23,845 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:23,914 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:24,092 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:24,303 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:24,520 - INFO - Gambar resolusi tinggi di-downscale dari 3127x4160 ke 811x1080 (max 1080px).
# 2026-07-02 02:40:24,603 - INFO - Gambar resolusi tinggi di-downscale dari 1204x1600 ke 812x1080 (max 1080px).
# 2026-07-02 02:40:24,670 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:24,742 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:24,815 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:25,022 - INFO - Gambar resolusi tinggi di-downscale dari 4000x3000 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:25,092 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:25,684 - INFO - Gambar resolusi tinggi di-downscale dari 4032x2268 ke 1080x607 (max 1080px).
# 2026-07-02 02:40:25,789 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-02 02:40:25,845 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-02 02:40:25,916 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:26,127 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:26,329 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:26,398 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:26,466 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1207 ke 1046x1080 (max 1080px).
# 2026-07-02 02:40:26,726 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:26,884 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-02 02:40:26,967 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:27,047 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:27,201 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-02 02:40:27,303 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-02 02:40:27,559 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:27,697 - INFO - Gambar resolusi tinggi di-downscale dari 1536x2730 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:27,778 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:27,873 - INFO - Gambar resolusi tinggi di-downscale dari 1600x930 ke 1080x627 (max 1080px).
# 2026-07-02 02:40:28,014 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-02 02:40:28,099 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:28,184 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:28,282 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:28,711 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:28,858 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 02:40:28,947 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:29,038 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:29,132 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:29,217 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:29,301 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:29,389 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:29,455 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:29,522 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:29,639 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-02 02:40:29,756 - INFO - Gambar resolusi tinggi di-downscale dari 1600x900 ke 1080x607 (max 1080px).
# 2026-07-02 02:40:30,060 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:30,201 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:30,291 - INFO - Gambar resolusi tinggi di-downscale dari 1024x1536 ke 720x1080 (max 1080px).
# 2026-07-02 02:40:30,370 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:30,450 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1065 ke 1080x718 (max 1080px).
# 2026-07-02 02:40:30,608 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:30,688 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:30,784 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:30,877 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:30,960 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:31,048 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:31,124 - INFO - Gambar resolusi tinggi di-downscale dari 1280x854 ke 1080x720 (max 1080px).
# 2026-07-02 02:40:31,195 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:31,505 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:31,604 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:31,676 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:31,841 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:32,156 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:32,245 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:32,318 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:32,394 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:32,460 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:32,656 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:32,868 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:33,081 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:33,145 - INFO - Gambar resolusi tinggi di-downscale dari 591x1280 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:33,373 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:33,436 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:33,508 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 02:40:33,625 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:33,691 - INFO - Gambar resolusi tinggi di-downscale dari 1280x724 ke 1080x610 (max 1080px).
# 2026-07-02 02:40:33,940 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:34,037 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:34,143 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:34,240 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:34,318 - INFO - Gambar resolusi tinggi di-downscale dari 610x1356 ke 485x1080 (max 1080px).
# 2026-07-02 02:40:34,457 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1762 ke 1080x647 (max 1080px).
# 2026-07-02 02:40:34,530 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-02 02:40:34,675 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-02 02:40:34,790 - INFO - Gambar resolusi tinggi di-downscale dari 3840x2160 ke 1080x607 (max 1080px).
# 2026-07-02 02:40:34,860 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:34,958 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:35,050 - INFO - Gambar resolusi tinggi di-downscale dari 1600x853 ke 1080x575 (max 1080px).
# 2026-07-02 02:40:35,331 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:35,605 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:35,709 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:35,793 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:35,855 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1002 ke 1080x924 (max 1080px).
# 2026-07-02 02:40:35,918 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-02 02:40:36,005 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:36,101 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:36,164 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:36,214 - INFO - Gambar resolusi tinggi di-downscale dari 815x1180 ke 745x1080 (max 1080px).
# 2026-07-02 02:40:36,401 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:36,593 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:36,655 - INFO - Gambar resolusi tinggi di-downscale dari 1280x996 ke 1080x840 (max 1080px).
# 2026-07-02 02:40:36,732 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:36,949 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:37,019 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1272 ke 1080x1073 (max 1080px).
# 2026-07-02 02:40:37,264 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:37,328 - INFO - Gambar resolusi tinggi di-downscale dari 1600x894 ke 1080x603 (max 1080px).
# 2026-07-02 02:40:37,388 - INFO - Gambar resolusi tinggi di-downscale dari 871x1600 ke 587x1080 (max 1080px).
# 2026-07-02 02:40:37,498 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:37,570 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:37,793 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:37,859 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 02:40:37,925 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:38,097 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-02 02:40:38,282 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-02 02:40:38,489 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-02 02:40:38,554 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:38,837 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:38,899 - INFO - Gambar resolusi tinggi di-downscale dari 1280x782 ke 1080x659 (max 1080px).
# 2026-07-02 02:40:38,988 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:39,067 - INFO - Gambar resolusi tinggi di-downscale dari 3027x1638 ke 1080x584 (max 1080px).
# 2026-07-02 02:40:39,154 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:39,243 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 02:40:39,308 - INFO - Gambar resolusi tinggi di-downscale dari 583x1600 ke 393x1080 (max 1080px).
# 2026-07-02 02:40:39,361 - INFO - Gambar resolusi tinggi di-downscale dari 1296x892 ke 1080x743 (max 1080px).
# 2026-07-02 02:40:39,417 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:39,499 - INFO - Gambar resolusi tinggi di-downscale dari 2595x1638 ke 1080x681 (max 1080px).
# 2026-07-02 02:40:39,604 - INFO - Gambar resolusi tinggi di-downscale dari 2932x1760 ke 1080x648 (max 1080px).
# 2026-07-02 02:40:39,668 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:39,804 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:39,944 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:40,078 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:40,225 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:40,347 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:40,478 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:40,653 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:40,777 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:40,907 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 02:40:41,073 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# Berhasil mengumpulkan 7837 wajah dari 1000 gambar uji dalam 130.29 detik (deteksi+alignment).

# %% [markdown]
# ## 2. Metode Berbasis Geometri: Geometry-Based Landmarks
# Metode berbasis geometri mengidentifikasi wajah dengan mengukur jarak relatif antar landmark wajah utama seperti mata, hidung, dan mulut secara scale-invariant pada 6 jarak Euclidean berpasangan.

# %%
def extract_geometry_features(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    h_idx, w_idx = gray.shape
    
    def get_landmark_centroid(y_start, y_end, x_start, x_end):
        ys, ye = int(y_start * h_idx), int(y_end * h_idx)
        xs, xe = int(x_start * w_idx), int(x_end * w_idx)
        sub_img = gray[ys:ye, xs:xe]
        
        threshold = np.percentile(sub_img, 10)
        dark_pixels = np.argwhere(sub_img <= threshold)
        if len(dark_pixels) == 0:
            cy, cx = (ys + ye) / 2, (xs + xe) / 2
        else:
            cy = ys + np.mean(dark_pixels[:, 0])
            cx = xs + np.mean(dark_pixels[:, 1])
        return np.array([cx, cy])
        
    left_eye = get_landmark_centroid(0.2, 0.4, 0.2, 0.45)
    right_eye = get_landmark_centroid(0.2, 0.4, 0.55, 0.8)
    nose = get_landmark_centroid(0.45, 0.7, 0.4, 0.6)
    mouth = get_landmark_centroid(0.7, 0.95, 0.3, 0.7)
    
    dists = [
        np.linalg.norm(left_eye - right_eye),
        np.linalg.norm(left_eye - nose),
        np.linalg.norm(right_eye - nose),
        np.linalg.norm(left_eye - mouth),
        np.linalg.norm(right_eye - mouth),
        np.linalg.norm(nose - mouth)
    ]
    
    eye_dist = dists[0] if dists[0] > 0 else 1.0
    normalized_dists = [d / eye_dist for d in dists]
    return np.array(normalized_dists, dtype=np.float32)

print("Evaluasi Geometry-Based...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_geometry_features(face) for p, face in query_faces.items()}
dataset_feats = np.array([extract_geometry_features(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('Geometry-Based', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi Geometry-Based...
# --- Geometry-Based Evaluated ---
# Best Threshold: 0.05
# Accuracy      : 0.2900
# F1-Score      : 0.3990

# %% [markdown]
# ## 3. Metode Holistik: PCA (Eigenfaces)
# Principal Component Analysis (PCA) mereduksi dimensi gambar dari wajah ter-resize dengan memproyeksikannya ke eigenfaces berdimensi 150.

# %%
print("Evaluasi PCA (Eigenfaces)... ")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Flatten wajah ke grayscale
def flatten_gray_face(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    return gray.flatten().astype(np.float32) / 255.0

query_flat = np.array([flatten_gray_face(query_faces[p]) for p in ["A", "B", "C"]])
dataset_flat = np.array([flatten_gray_face(f["cropped_face"]) for f in dataset_faces])

# 2. Fit PCA pada kumpulan wajah dataset
n_components = min(150, len(dataset_faces))
pca = PCA(n_components=n_components, svd_solver='randomized', whiten=True)
pca.fit(dataset_flat)

# 3. Proyeksi
query_projected = pca.transform(query_flat)
dataset_projected = pca.transform(dataset_flat)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('PCA (Holistik)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi PCA (Eigenfaces)...
# --- PCA (Holistik) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.5057
# F1-Score      : 0.4473

# %% [markdown]
# ## 4. Metode Berbasis Fitur: LBP & HOG
# Mengekstrak fitur lokal menggunakan **Local Binary Pattern (LBP)** dan **Histogram of Oriented Gradients (HOG)**.

# %%
def extract_lbp_hist(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    n_bins = n_points + 2
    hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=(0, n_bins), density=True)
    return hist.astype(np.float32)

print("Evaluasi LBP...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_lbp_hist(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_lbp_hist(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

def extract_hog_vector(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    feat = hog(gray, orientations=8, pixels_per_cell=(8, 8),
               cells_per_block=(2, 2), visualize=False)
    return feat.astype(np.float32)

print("\nEvaluasi HOG...")
mem_before = get_memory_usage()
t0 = time.time()

query_feats = {p: extract_hog_vector(query_faces[p]) for p in ["A", "B", "C"]}
dataset_feats = np.array([extract_hog_vector(f["cropped_face"]) for f in dataset_faces])

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('HOG (Berbasis Fitur)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP...
# --- LBP (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.30
# Accuracy      : 0.3720
# F1-Score      : 0.4189
#
# Evaluasi HOG...
# --- HOG (Berbasis Fitur) Evaluated ---
# Best Threshold: 0.30
# Accuracy      : 0.5877
# F1-Score      : 0.4675

# %% [markdown]
# ## 5. Metode Hibrida: LBP + PCA
# Menggabungkan tekstur lokal dari LBP mentah dengan reduksi dimensi PCA (50 komponen).

# %%
def extract_raw_lbp(face_img, radius=1, n_points=8):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method="uniform")
    return lbp.ravel().astype(np.float32)

print("Evaluasi LBP + PCA (Hibrida)...")
mem_before = get_memory_usage()
t0 = time.time()

query_raw_lbp = np.array([extract_raw_lbp(query_faces[p]) for p in ["A", "B", "C"]])
dataset_raw_lbp = np.array([extract_raw_lbp(f["cropped_face"]) for f in dataset_faces])

n_components_hyb = min(50, len(dataset_faces))
pca_lbp = PCA(n_components=n_components_hyb, svd_solver='randomized', whiten=True)
pca_lbp.fit(dataset_raw_lbp)

query_projected = pca_lbp.transform(query_raw_lbp)
dataset_projected = pca_lbp.transform(dataset_raw_lbp)

query_feats = {p: query_projected[i] for i, p in enumerate(["A", "B", "C"])}

feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('LBP + PCA (Hibrida)', query_feats, dataset_projected, dataset_faces, feat_time, mem_used)
# Out:
# Evaluasi LBP + PCA (Hibrida)...
# --- LBP + PCA (Hibrida) Evaluated ---
# Best Threshold: 0.95
# Accuracy      : 0.4090
# F1-Score      : 0.4020

# %% [markdown]
# ## 6. Metode Deep Learning: Facenet (DeepFace)
# Mengekstrak embedding berdimensi 128 dari model Deep Learning Facenet (diload dari cache jika tersedia).

# %%
print("Evaluasi Facenet...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="Facenet", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    # Cek cache Facenet
    cached_found = False
    if img_name in preloaded_caches["Facenet"]:
        for cached_entry in preloaded_caches["Facenet"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        # Ekstraksi Baru dan simpan cache
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "Facenet")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["Facenet"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 100 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (Facenet)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi Facenet...
# --- DeepFace (Facenet) Evaluated ---
# Best Threshold: 0.40
# Accuracy      : 0.8890
# F1-Score      : 0.7630
# 759

# %% [markdown]
# ## 7. Metode Deep Learning: VGG-Face (DeepFace)
# Mengekstrak embedding berdimensi 2622 dari model Deep Learning VGG-Face (diload dari cache jika tersedia).

# %%
print("Evaluasi VGG-Face...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="VGG-Face", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["VGG-Face"]:
        for cached_entry in preloaded_caches["VGG-Face"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "VGG-Face")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["VGG-Face"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (VGG-Face)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras untuk mengosongkan RAM sebelum memuat model berikutnya
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi VGG-Face...
# --- DeepFace (VGG-Face) Evaluated ---
# Best Threshold: 0.60
# Accuracy      : 0.9220
# F1-Score      : 0.8186
# 338

# %% [markdown]
# ## 8. Metode Deep Learning: ArcFace (DeepFace)
# Mengekstrak embedding berdimensi 512 dari model Deep Learning ArcFace (diload dari cache jika tersedia). Ini adalah model yang digunakan oleh sistem utama GUI.

# %%
print("Evaluasi ArcFace...")
mem_before = get_memory_usage()
t0 = time.time()

# 1. Ekstraksi Fitur Kueri
query_feats = {}
for p in ["A", "B", "C"]:
    q_img = cv2.cvtColor(query_faces[p], cv2.COLOR_GRAY2BGR) if len(query_faces[p].shape) == 2 else query_faces[p]
    rep = DeepFace.represent(img_path=q_img, model_name="ArcFace", enforce_detection=False, detector_backend="skip")
    query_feats[p] = np.array(rep[0]["embedding"], dtype=np.float32)

# 2. Ekstraksi Fitur Dataset
dataset_feats_list = []
for idx, face_meta in enumerate(dataset_faces):
    img_name = face_meta["img_name"]
    bbox = face_meta["bbox"]
    
    cached_found = False
    if img_name in preloaded_caches["ArcFace"]:
        for cached_entry in preloaded_caches["ArcFace"][img_name]:
            if list(cached_entry["bbox"]) == list(bbox):
                dataset_feats_list.append(cached_entry["embedding"])
                cached_found = True
                break
                
    if not cached_found:
        import gc
        f_img = face_meta["cropped_face"]
        emb = extract_deepface_embedding(f_img, "ArcFace")
        norm = np.linalg.norm(emb)
        if norm > 0:
            emb = emb / norm
        handlers["ArcFace"].simpan_cache(img_name, emb, bbox)
        dataset_feats_list.append(emb)
        del f_img, emb
        if idx % 50 == 0:
            gc.collect()
dataset_feats = np.array(dataset_feats_list)
feat_time = time.time() - t0
mem_after = get_memory_usage()
mem_used = max(0, mem_after - mem_before)

evaluate_matching_model('DeepFace (ArcFace)', query_feats, dataset_feats, dataset_faces, feat_time, mem_used)

# Bersihkan session Keras setelah selesai pengujian
import tensorflow as tf
tf.keras.backend.clear_session()
import gc
gc.collect()
# Out:
# Evaluasi ArcFace...
# --- DeepFace (ArcFace) Evaluated ---
# Best Threshold: 0.60
# Accuracy      : 0.8910
# F1-Score      : 0.7547
# 140

# %% [markdown]
# ## 9. Visualisasi dan Perbandingan Kinerja
# Menampilkan tabel perbandingan DataFrame lengkap untuk kedelapan model, dan memvisualisasikan F1-Score, waktu eksekusi total (ekstraksi + pencocokan), serta tambahan penggunaan RAM.

# %%
df_results = pd.DataFrame(results)
print("\n--- Hasil Perbandingan Lengkap (8 Model) ---")
print(df_results.to_string(index=False))

# Tableau 10 color palette untuk visualisasi premium
colors = ['#4E79A7', '#F28E2B', '#E15759', '#76B7B2', '#59A14F', '#EDC948', '#B07AA1', '#FF9DA7']

plt.figure(figsize=(18, 6))

# 1. Plot F1-Score
plt.subplot(1, 3, 1)
bars1 = plt.bar(df_results['Model'], df_results['F1-Score'], color=colors[:len(df_results)])
plt.title('F1-Score Model (Tertinggi Terbaik)', fontsize=12, fontweight='bold')
plt.ylim(0, 1.15)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('F1-Score')
for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.02, f"{yval:.2f}", ha='center', va='bottom', fontsize=9)

# 2. Plot Stacked Waktu Komputasi per Tahap (Deteksi + Ekstraksi + Inferensi)
plt.subplot(1, 3, 2)
det_times = df_results['Detection Time (s)']
feat_times = df_results['Feature Extraction Time (s)']
infer_times = df_results['Inference Time (s)']
plt.bar(df_results['Model'], det_times, color='#B07AA1', label='Deteksi & Alignment')
plt.bar(df_results['Model'], feat_times, bottom=det_times, color='#4E79A7', label='Ekstraksi Fitur')
plt.bar(df_results['Model'], infer_times, bottom=det_times + feat_times, color='#F28E2B', label='Inferensi/Matching')
total_time = det_times + feat_times + infer_times
plt.title('Waktu Komputasi per Tahap (detik)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Waktu (detik)')
plt.legend(fontsize=7, loc='upper left')
for i, total in enumerate(total_time):
    plt.text(i, total + (total * 0.02) + 0.05, f"{total:.2f}s", ha='center', va='bottom', fontsize=9)

# 3. Plot Memory Usage
plt.subplot(1, 3, 3)
bars3 = plt.bar(df_results['Model'], df_results['Memory Usage (MB)'], color=colors[:len(df_results)])
plt.title('Penggunaan Memori Tambahan (MB)', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.ylabel('Memori (MB)')
for bar in bars3:
    yval = bar.get_height()
    # Jaga formatting
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.1, f"{yval:.1f} MB", ha='center', va='bottom', fontsize=9)

plt.tight_layout()
assets_dir = os.path.join(project_root, "assets")
os.makedirs(assets_dir, exist_ok=True)
plt.savefig(os.path.join(assets_dir, "perbandingan_kinerja_scrfd.png"), dpi=300, bbox_inches="tight")
plt.show()
# Out:
# --- Hasil Perbandingan Lengkap (8 Model) ---
#                Model  Accuracy  Precision   Recall  F1-Score  Best Threshold  Feature Extraction Time (s)  Inference Time (s)  Memory Usage (MB)  Detection Time (s)
#       Geometry-Based  0.290000   0.249207 1.000000  0.398984            0.05                     2.742812            9.907337           0.914062          130.288366
#       PCA (Holistik)  0.505667   0.303644 0.848656  0.447261            0.95                     5.637672            9.549112         418.167969          130.288366
# LBP (Berbasis Fitur)  0.372000   0.267850 0.960396  0.418877            0.30                    13.126712            8.610906           0.238281          130.288366
# HOG (Berbasis Fitur)  0.587667   0.336015 0.768034  0.467499            0.30                    22.117930            8.875079         164.261719          130.288366
#  LBP + PCA (Hibrida)  0.409000   0.263950 0.842999  0.402024            0.95                    13.765099           10.010304         374.984375          130.288366
#   DeepFace (Facenet)  0.889000   0.767908 0.758133  0.762989            0.40                  1875.325180            8.371983           0.000000          130.288366
#  DeepFace (VGG-Face)  0.922000   0.905660 0.746818  0.818605            0.60                  2100.629198            9.178297        1404.253906          130.288366
#   DeepFace (ArcFace)  0.891000   0.803514 0.711457  0.754689            0.60                  1766.404468            8.441509           0.000000          130.288366

# %%
DETECTOR_TYPE = "scrfd"

# %% [markdown]
# ## 10. Uji Skalabilitas: Waktu Pemrosesan vs Jumlah Data
#
# Bagian ini menguji ketiga model Deep Learning (**ArcFace**, **Facenet**, **VGG-Face**) pada lima ukuran dataset yang berbeda: 100, 300, 500, 700, dan 1000 gambar (`test_case_100` s.d. `test_case_700`, serta `test_case` untuk 1000 gambar). Untuk setiap ukuran data, dicatat waktu **deteksi & alignment wajah** serta waktu **ekstraksi fitur** per model, tanpa menggunakan cache, agar waktu yang terukur murni mencerminkan biaya komputasi untuk jumlah data tersebut.

# %%
SCALING_SIZES = [100, 300, 500, 700, 1000]
SCALING_MODELS = ["ArcFace", "Facenet", "VGG-Face"]

def get_scaling_dir(size):
    if size == 1000:
        return os.path.join(TESTSET_DIR, "test_case")
    return os.path.join(TESTSET_DIR, f"test_case_{size}")

scaling_results = {
    "Data Size": [],
    "Model": [],
    "Num Images": [],
    "Num Faces Detected": [],
    "Detection Time (s)": [],
    "Feature Extraction Time (s)": [],
    "Total Time (s)": []
}

# %%
import gc

for size in SCALING_SIZES:
    img_dir = get_scaling_dir(size)
    img_files = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    print(f"\n=== Ukuran Data: {size} ({len(img_files)} gambar ditemukan di {os.path.basename(img_dir)}) ===")

    # Deteksi & alignment wajah sekali per ukuran data, dipakai bersama oleh ketiga model
    t0 = time.time()
    scaling_faces = []
    for img_name in img_files:
        img_path = os.path.join(img_dir, img_name)
        rois = detector.detect_and_crop(img_path)
        for roi in rois:
            scaling_faces.append(roi["cropped_face"])
    det_time = time.time() - t0
    print(f"Deteksi: {len(scaling_faces)} wajah dalam {det_time:.2f} detik")

    for model_name in SCALING_MODELS:
        t0 = time.time()
        for face_img in scaling_faces:
            _ = extract_deepface_embedding(face_img, model_name)
        feat_time = time.time() - t0

        scaling_results["Data Size"].append(size)
        scaling_results["Model"].append(model_name)
        scaling_results["Num Images"].append(len(img_files))
        scaling_results["Num Faces Detected"].append(len(scaling_faces))
        scaling_results["Detection Time (s)"].append(det_time)
        scaling_results["Feature Extraction Time (s)"].append(feat_time)
        scaling_results["Total Time (s)"].append(det_time + feat_time)

        print(f"  {model_name}: ekstraksi {feat_time:.2f} detik (total {det_time + feat_time:.2f} detik)")
        gc.collect()

    del scaling_faces
    gc.collect()

import tensorflow as tf
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 2026-07-02 04:18:35,671 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:35,828 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# === Ukuran Data: 100 (100 gambar ditemukan di test_case_100) ===
# 2026-07-02 04:18:35,900 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:35,981 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,053 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,133 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,205 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,284 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,359 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,434 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,558 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,651 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,732 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,808 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,890 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:36,979 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:37,061 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:37,130 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:37,202 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:37,577 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 04:18:38,229 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-02 04:18:38,457 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 04:18:38,541 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 04:18:38,621 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:38,696 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:38,766 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:38,856 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:38,955 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:39,045 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:39,129 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:39,220 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:39,312 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:18:39,397 - INFO - Gambar resolusi tinggi di-downscale dari 1152x768 ke 1080x720 (max 1080px).
# 2026-07-02 04:18:39,476 - INFO - Gambar resolusi tinggi di-downscale dari 588x1280 ke 496x1080 (max 1080px).
# 2026-07-02 04:18:39,549 - INFO - Gambar resolusi tinggi di-downscale dari 640x1280 ke 540x1080 (max 1080px).
# 2026-07-02 04:18:39,757 - INFO - Gambar resolusi tinggi di-downscale dari 682x1280 ke 575x1080 (max 1080px).
# 2026-07-02 04:18:39,823 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-02 04:18:39,897 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-02 04:18:40,220 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-02 04:18:40,323 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-02 04:18:40,410 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-07-02 04:18:40,496 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-02 04:18:40,698 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-02 04:18:40,795 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:41,589 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 04:18:41,675 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-02 04:18:41,756 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-02 04:18:41,834 - INFO - Gambar resolusi tinggi di-downscale dari 1280x597 ke 1080x503 (max 1080px).
# 2026-07-02 04:18:42,558 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-02 04:18:42,672 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:42,760 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-07-02 04:18:42,861 - INFO - Gambar resolusi tinggi di-downscale dari 1280x963 ke 1080x812 (max 1080px).
# 2026-07-02 04:18:43,028 - INFO - Gambar resolusi tinggi di-downscale dari 1201x1600 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:43,118 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:43,216 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:43,310 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 04:18:43,414 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1202 ke 1080x811 (max 1080px).
# 2026-07-02 04:18:43,505 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 04:18:43,592 - INFO - Gambar resolusi tinggi di-downscale dari 872x1160 ke 811x1080 (max 1080px).
# 2026-07-02 04:18:43,672 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# Deteksi: 745 wajah dalam 8.08 detik
#   ArcFace: ekstraksi 146.05 detik (total 154.13 detik)
#   Facenet: ekstraksi 163.34 detik (total 171.43 detik)
#   VGG-Face: ekstraksi 188.29 detik (total 196.37 detik)
# 2026-07-02 04:27:02,364 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:02,443 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:02,526 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# === Ukuran Data: 300 (300 gambar ditemukan di test_case_300) ===
# 2026-07-02 04:27:02,609 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:02,700 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:02,789 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:02,872 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:02,953 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,036 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,126 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,209 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,295 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,378 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,457 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,539 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,618 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,703 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,789 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:03,868 - INFO - Gambar resolusi tinggi di-downscale dari 1108x1477 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:04,212 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 04:27:04,891 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1280 ke 1080x1080 (max 1080px).
# 2026-07-02 04:27:05,083 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 04:27:05,150 - INFO - Gambar resolusi tinggi di-downscale dari 1280x960 ke 1080x810 (max 1080px).
# 2026-07-02 04:27:05,226 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,291 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,357 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,433 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,508 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,590 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,659 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,753 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,836 - INFO - Gambar resolusi tinggi di-downscale dari 1280x720 ke 1080x607 (max 1080px).
# 2026-07-02 04:27:05,914 - INFO - Gambar resolusi tinggi di-downscale dari 1152x768 ke 1080x720 (max 1080px).
# 2026-07-02 04:27:05,976 - INFO - Gambar resolusi tinggi di-downscale dari 588x1280 ke 496x1080 (max 1080px).
# 2026-07-02 04:27:06,034 - INFO - Gambar resolusi tinggi di-downscale dari 640x1280 ke 540x1080 (max 1080px).
# 2026-07-02 04:27:06,221 - INFO - Gambar resolusi tinggi di-downscale dari 682x1280 ke 575x1080 (max 1080px).
# 2026-07-02 04:27:06,283 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-02 04:27:06,346 - INFO - Gambar resolusi tinggi di-downscale dari 606x1280 ke 511x1080 (max 1080px).
# 2026-07-02 04:27:06,633 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-02 04:27:06,726 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1279 ke 1080x1079 (max 1080px).
# 2026-07-02 04:27:06,807 - INFO - Gambar resolusi tinggi di-downscale dari 1280x853 ke 1080x719 (max 1080px).
# 2026-07-02 04:27:06,876 - INFO - Gambar resolusi tinggi di-downscale dari 540x1200 ke 486x1080 (max 1080px).
# 2026-07-02 04:27:07,045 - INFO - Gambar resolusi tinggi di-downscale dari 720x1600 ke 486x1080 (max 1080px).
# 2026-07-02 04:27:07,125 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 04:27:07,838 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 04:27
- INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:58,071 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 06:46:58,159 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 06:46:58,473 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-02 06:46:58,576 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:58,661 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:58,737 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:58,821 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:59,052 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:59,278 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:59,507 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:59,577 - INFO - Gambar resolusi tinggi di-downscale dari 591x1280 ke 498x1080 (max 1080px).
# 2026-07-02 06:46:59,849 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 06:46:59,925 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:00,003 - INFO - Gambar resolusi tinggi di-downscale dari 739x1600 ke 498x1080 (max 1080px).
# 2026-07-02 06:47:00,107 - INFO - Gambar resolusi tinggi di-downscale dari 899x1599 ke 607x1080 (max 1080px).
# 2026-07-02 06:47:00,197 - INFO - Gambar resolusi tinggi di-downscale dari 1280x724 ke 1080x610 (max 1080px).
# 2026-07-02 06:47:00,438 - INFO - Gambar resolusi tinggi di-downscale dari 3000x4000 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:00,536 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:00,626 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:00,712 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:00,794 - INFO - Gambar resolusi tinggi di-downscale dari 610x1356 ke 485x1080 (max 1080px).
# 2026-07-02 06:47:00,922 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1762 ke 1080x647 (max 1080px).
# 2026-07-02 06:47:00,990 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-02 06:47:01,123 - INFO - Gambar resolusi tinggi di-downscale dari 2940x1912 ke 1080x702 (max 1080px).
# 2026-07-02 06:47:01,254 - INFO - Gambar resolusi tinggi di-downscale dari 3840x2160 ke 1080x607 (max 1080px).
# 2026-07-02 06:47:01,330 - INFO - Gambar resolusi tinggi di-downscale dari 720x1280 ke 607x1080 (max 1080px).
# 2026-07-02 06:47:01,426 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:01,516 - INFO - Gambar resolusi tinggi di-downscale dari 1600x853 ke 1080x575 (max 1080px).
# 2026-07-02 06:47:01,812 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:02,049 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:02,163 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:02,258 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 06:47:02,333 - INFO - Gambar resolusi tinggi di-downscale dari 1170x1002 ke 1080x924 (max 1080px).
# 2026-07-02 06:47:02,409 - INFO - Gambar resolusi tinggi di-downscale dari 1280x832 ke 1080x702 (max 1080px).
# 2026-07-02 06:47:02,505 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:02,622 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:02,716 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 06:47:02,777 - INFO - Gambar resolusi tinggi di-downscale dari 815x1180 ke 745x1080 (max 1080px).
# 2026-07-02 06:47:03,025 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:03,286 - INFO - Gambar resolusi tinggi di-downscale dari 3024x4032 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:03,368 - INFO - Gambar resolusi tinggi di-downscale dari 1280x996 ke 1080x840 (max 1080px).
# 2026-07-02 06:47:03,470 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:03,764 - INFO - Gambar resolusi tinggi di-downscale dari 3120x4160 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:03,862 - INFO - Gambar resolusi tinggi di-downscale dari 1280x1272 ke 1080x1073 (max 1080px).
# 2026-07-02 06:47:04,199 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:04,290 - INFO - Gambar resolusi tinggi di-downscale dari 1600x894 ke 1080x603 (max 1080px).
# 2026-07-02 06:47:04,368 - INFO - Gambar resolusi tinggi di-downscale dari 871x1600 ke 587x1080 (max 1080px).
# 2026-07-02 06:47:04,512 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:04,616 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:04,892 - INFO - Gambar resolusi tinggi di-downscale dari 4032x3024 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:04,980 - INFO - Gambar resolusi tinggi di-downscale dari 900x1600 ke 607x1080 (max 1080px).
# 2026-07-02 06:47:05,069 - INFO - Gambar resolusi tinggi di-downscale dari 1599x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:05,289 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-02 06:47:05,517 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-02 06:47:05,770 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4080 ke 813x1080 (max 1080px).
# 2026-07-02 06:47:05,848 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:06,220 - INFO - Gambar resolusi tinggi di-downscale dari 4160x3120 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:06,301 - INFO - Gambar resolusi tinggi di-downscale dari 1280x782 ke 1080x659 (max 1080px).
# 2026-07-02 06:47:06,414 - INFO - Gambar resolusi tinggi di-downscale dari 1200x1600 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:06,520 - INFO - Gambar resolusi tinggi di-downscale dari 3027x1638 ke 1080x584 (max 1080px).
# 2026-07-02 06:47:06,633 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:06,738 - INFO - Gambar resolusi tinggi di-downscale dari 1600x1200 ke 1080x810 (max 1080px).
# 2026-07-02 06:47:06,826 - INFO - Gambar resolusi tinggi di-downscale dari 583x1600 ke 393x1080 (max 1080px).
# 2026-07-02 06:47:06,890 - INFO - Gambar resolusi tinggi di-downscale dari 1296x892 ke 1080x743 (max 1080px).
# 2026-07-02 06:47:06,973 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:07,082 - INFO - Gambar resolusi tinggi di-downscale dari 2595x1638 ke 1080x681 (max 1080px).
# 2026-07-02 06:47:07,221 - INFO - Gambar resolusi tinggi di-downscale dari 2932x1760 ke 1080x648 (max 1080px).
# 2026-07-02 06:47:07,308 - INFO - Gambar resolusi tinggi di-downscale dari 960x1280 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:07,502 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:07,688 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:07,859 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:08,039 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:08,219 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:08,477 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:08,705 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:08,903 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:09,106 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# 2026-07-02 06:47:09,318 - INFO - Gambar resolusi tinggi di-downscale dari 3072x4096 ke 810x1080 (max 1080px).
# Deteksi: 7837 wajah dalam 136.14 detik
#   ArcFace: ekstraksi 1582.24 detik (total 1718.38 detik)
#   Facenet: ekstraksi 1800.78 detik (total 1936.92 detik)
#   VGG-Face: ekstraksi 1996.10 detik (total 2132.24 detik)
# 107

# %%
df_scaling = pd.DataFrame(scaling_results)
print("\n--- Hasil Uji Skalabilitas (Waktu vs Jumlah Data) ---")
print(df_scaling.to_string(index=False))

scaling_colors = {'ArcFace': '#4E79A7', 'Facenet': '#F28E2B', 'VGG-Face': '#E15759'}

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
for model_name in SCALING_MODELS:
    subset = df_scaling[df_scaling["Model"] == model_name]
    plt.plot(subset["Data Size"], subset["Total Time (s)"], marker='o', label=model_name, color=scaling_colors[model_name])
plt.title("Waktu Total (Deteksi + Ekstraksi) vs Jumlah Data", fontsize=12, fontweight="bold")
plt.xlabel("Jumlah Gambar")
plt.ylabel("Waktu Total (detik)")
plt.legend()
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
for model_name in SCALING_MODELS:
    subset = df_scaling[df_scaling["Model"] == model_name]
    plt.plot(subset["Data Size"], subset["Feature Extraction Time (s)"], marker='o', label=model_name, color=scaling_colors[model_name])
plt.title("Waktu Ekstraksi Fitur vs Jumlah Data", fontsize=12, fontweight="bold")
plt.xlabel("Jumlah Gambar")
plt.ylabel("Waktu Ekstraksi (detik)")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
assets_dir = os.path.join(project_root, "assets")
os.makedirs(assets_dir, exist_ok=True)
plt.savefig(os.path.join(assets_dir, f"uji_skalabilitas_{DETECTOR_TYPE}.png"), dpi=300, bbox_inches="tight")
plt.show()
# Out:
# --- Hasil Uji Skalabilitas (Waktu vs Jumlah Data) ---
#  Data Size    Model  Num Images  Num Faces Detected  Detection Time (s)  Feature Extraction Time (s)  Total Time (s)
#        100  ArcFace         100                 745            8.084313                   146.045288      154.129601
#        100  Facenet         100                 745            8.084313                   163.340829      171.425142
#        100 VGG-Face         100                 745            8.084313                   188.285623      196.369936
#        300  ArcFace         300                2698           40.009593                   547.689189      587.698783
#        300  Facenet         300                2698           40.009593                   647.146503      687.156097
#        300 VGG-Face         300                2698           40.009593                   670.302215      710.311809
#        500  ArcFace         500                3729           62.650205                   686.803884      749.454088
#        500  Facenet         500                3729           62.650205                   782.102198      844.752403
#        500 VGG-Face         500                3729           62.650205                   816.238981      878.889186
#        700  ArcFace         700                5915           79.368545                  1235.164545     1314.533090
#        700  Facenet         700                5915           79.368545                  1294.131631     1373.500176
#        700 VGG-Face         700                5915           79.368545                  1406.122352     1485.490897
#       1000  ArcFace        1000                7837          136.140787                  1582.243441     1718.384228
#       1000  Facenet        1000                7837          136.140787                  1800.779246     1936.920033
#       1000 VGG-Face        1000                7837          136.140787                  1996.097765     2132.238552
